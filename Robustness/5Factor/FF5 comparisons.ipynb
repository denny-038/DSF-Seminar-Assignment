# %%
import pandas as pd
import statsmodels.api as sm

# Load your data from Excel
df = pd.read_excel('climate_final_with_ff5_and_excess_return.xlsx', sheet_name='climate_final_with_ff5_and_exce', parse_dates=['date'])

# Define your factor lists
fama_french_factors = ['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA']
env_factors = ['Overall_ESG_Exposure', 'Overall_ESG_Sentiment']

# Helper function to run regressions and collect results
def run_regression(y, X):
    X = sm.add_constant(X)
    model = sm.OLS(y, X).fit()
    results = {}
    for var in X.columns:
        results[f'{var}_coef'] = model.params[var]
        results[f'{var}_stderr'] = model.bse[var]  
    results['R2'] = model.rsquared
    results['Adj_R2'] = model.rsquared_adj
    results['n_obs']   = int(model.nobs)
    return results

# --- 1. Macro Sector Level Regression ---
sector_results_fama = []
sector_results_fama_env = []

for sector, group in df.groupby('Macro_Sector'):
    # Fama-French only
    res_fama = run_regression(group['excess_RET'], group[fama_french_factors])
    res_fama['Macro_Sector'] = sector
    sector_results_fama.append(res_fama)
    
    # Fama-French + ENV
    res_fama_env = run_regression(group['excess_RET'], group[fama_french_factors + env_factors])
    res_fama_env['Macro_Sector'] = sector
    sector_results_fama_env.append(res_fama_env)

sector_df_fama = pd.DataFrame(sector_results_fama)
sector_df_fama_env = pd.DataFrame(sector_results_fama_env)

# --- 2. Ticker Level Regression (within each Macro Sector) ---
ticker_results = []

ticker_groups = df.groupby(['Macro_Sector', 'TICKER'])

for (sector, ticker), group in ticker_groups:
    res = run_regression(group['excess_RET'], group[fama_french_factors + env_factors])
    res['Macro_Sector'] = sector
    res['Ticker'] = ticker
    ticker_results.append(res)

full_ticker_df = pd.DataFrame(ticker_results)

# --- 3. Pretty-printing ---
# Split ticker results by sector
industrials = full_ticker_df[full_ticker_df['Macro_Sector'] == 'Industrials']
consumer = full_ticker_df[full_ticker_df['Macro_Sector'] == 'Consumer']
energy_utilities = full_ticker_df[full_ticker_df['Macro_Sector'] == 'Energy & Utilities']

# Print results
print("\n=== Macro-Sector Level Regression: Fama-French Only ===")
print(sector_df_fama.round(4))

print("\n=== Macro-Sector Level Regression: Fama-French + ENV Factors ===")
print(sector_df_fama_env.round(4))

print("\n=== Ticker-Level Regression: Industrials ===")
print(industrials.round(4))

print("\n=== Ticker-Level Regression: Consumer ===")
print(consumer.round(4))

print("\n=== Ticker-Level Regression: Energy & Utilities ===")
print(energy_utilities.round(4))

print("\nDone! All tables printed.")
# Out:
# === Macro-Sector Level Regression: Fama-French Only ===
#    const_coef  const_stderr  Mkt-RF_coef  Mkt-RF_stderr  SMB_coef  SMB_stderr  \
# 0     -0.0034        0.0023       1.0880         0.0478    0.2473      0.0939
# 1     -0.0033        0.0023       0.7781         0.0481   -0.1016      0.0949
# 2     -0.0028        0.0017       0.9543         0.0349    0.1912      0.0690
#
#    HML_coef  HML_stderr  RMW_coef  RMW_stderr  CMA_coef  CMA_stderr      R2  \
# 0    0.0279      0.0793    0.2349      0.1078   -0.0072      0.1126  0.3478
# 1    0.2424      0.0797    0.1790      0.1085    0.3939      0.1132  0.2976
# 2    0.1192      0.0579    0.2319      0.0789    0.1330      0.0823  0.3019
#
#    Adj_R2  n_obs        Macro_Sector
# 0  0.3455   1412            Consumer
# 1  0.2937    910  Energy & Utilities
# 2  0.3005   2520         Industrials
#
# === Macro-Sector Level Regression: Fama-French + ENV Factors ===
#    const_coef  const_stderr  Mkt-RF_coef  Mkt-RF_stderr  SMB_coef  SMB_stderr  \
# 0      0.0032        0.0056       1.0891         0.0478    0.2452      0.0940
# 1     -0.0043        0.0070       0.7790         0.0481   -0.0974      0.0951
# 2      0.0010        0.0035       0.9554         0.0350    0.1875      0.0690
#
#    HML_coef  HML_stderr  RMW_coef  RMW_stderr  CMA_coef  CMA_stderr  \
# 0    0.0284      0.0793    0.2330      0.1078   -0.0107      0.1127
# 1    0.2354      0.0800    0.1791      0.1086    0.4011      0.1135
# 2    0.1218      0.0580    0.2290      0.0789    0.1245      0.0824
#
#    Overall_ESG_Exposure_coef  Overall_ESG_Exposure_stderr  \
# 0                    -0.1212                       0.1089
# 1                    -0.0096                       0.0160
# 2                     0.0117                       0.0190
#
#    Overall_ESG_Sentiment_coef  Overall_ESG_Sentiment_stderr      R2  Adj_R2  \
# 0                     -0.0124                        0.0146  0.3487  0.3454
# 1                      0.0173                        0.0215  0.2985  0.2931
# 2                     -0.0174                        0.0102  0.3029  0.3009
#
#    n_obs        Macro_Sector
# 0   1412            Consumer
# 1    910  Energy & Utilities
# 2   2520         Industrials
#
# === Ticker-Level Regression: Industrials ===
#     const_coef  const_stderr  Mkt-RF_coef  Mkt-RF_stderr  SMB_coef  \
# 33      0.0102        0.0361       0.5299         0.1680    0.3037
# 34     -0.0447        0.0420       0.8285         0.1072    0.0037
# 35      0.0699        0.0440       1.2619         0.2504   -0.4179
# 36      0.0024        0.0521       1.1519         0.0989    0.0958
# 37     -0.0398        0.0308       1.4432         0.2035    1.3633
# 38     -0.0108        0.0350      -0.0078         0.2643    0.5252
# 39      0.0071        0.0599       1.3672         0.1635   -0.2666
# 40     -0.0715        0.0766       0.8521         0.1286   -0.4569
# 41      0.0792        0.2315       0.9828         0.2219    0.5453
# 42     -0.0084        0.0751       0.8133         0.2231    0.6086
# 43      0.0642        0.0367       1.0060         0.1348    0.1536
# 44      0.0133        0.0121       0.7901         0.1482   -0.0121
# 45     -0.0062        0.0151       0.8505         0.2100    0.7601
# 46      0.0237        0.0263       1.0457         0.2685    0.0884
# 47      0.0293        0.1461       1.2856         0.2029    0.5641
# 48      0.0412        0.0614       0.5267         0.2000    0.0954
# 49     -0.0092        0.0772       1.5137         0.1783   -0.4930
# 50     -0.0093        0.0138       0.5867         0.0996    0.0837
# 51      0.0283        0.0546       0.5749         0.1000   -0.3319
# 52     -0.0518        0.0901       0.7444         0.2422    0.0668
# 53     -0.0023        0.0166       1.3390         0.1937    0.4767
# 54     -0.0422        0.0360       0.5969         0.1031   -0.1999
# 55     -0.0222        0.0577       2.2482         0.3433    0.5790
# 56      0.0029        0.0241       0.5275         0.0872   -0.1174
# 57     -0.1345        0.1526       0.5666         0.1290    0.0060
# 58     -0.0157        0.2162       1.0892         0.1243    0.1601
# 59      0.2223        0.1770       2.2396         0.3173    0.3520
# 60      0.0485        0.0430       0.2993         0.2396   -0.1728
# 61     -0.0499        0.0127       0.9117         0.1696    1.0592
# 62     -0.0187        0.0117       0.5776         0.1378   -0.2761
# 63     -0.0177        0.0197       1.3443         0.1495    0.6515
# 64      0.0544        0.0365       1.3092         0.2960    0.6194
# 65     -0.0112        0.0388       0.5091         0.1228   -0.4572
# 66     -0.0520        0.0788       0.7683         0.1977    0.5913
# 67      0.0048        0.0410       1.0283         0.1393   -0.2348
# 68      0.0317        0.0359       0.6923         0.1393    0.3754
#
#     SMB_stderr  HML_coef  HML_stderr  RMW_coef  RMW_stderr  ...  CMA_stderr  \
# 33      0.3326   -0.0369      0.2857    0.4349      0.3803  ...      0.4093
# 34      0.2129   -0.5300      0.1852    0.0515      0.2380  ...      0.2586
# 35      0.4919   -0.8003      0.4230    0.3468      0.5660  ...      0.6089
# 36      0.1996    0.2171      0.1690    0.5022      0.2260  ...      0.2373
# 37      0.3963    0.0242      0.3401    1.4390      0.4611  ...      0.4744
# 38      0.5403   -0.5641      0.4528    0.0740      0.6022  ...      0.6544
# 39      0.3202    0.5819      0.2753   -0.1223      0.3705  ...      0.3861
# 40      0.2568    0.0165      0.2253   -0.0543      0.2875  ...      0.3116
# 41      0.4404    0.5069      0.3770   -0.3458      0.5009  ...      0.5399
# 42      0.4411    0.1960      0.3855    0.9239      0.5050  ...      0.5413
# 43      0.2616    0.4579      0.2231   -0.0180      0.3049  ...      0.3132
# 44      0.2942   -0.2427      0.2535    0.2047      0.3327  ...      0.3644
# 45      0.4239   -0.4055      0.3560    1.1215      0.4804  ...      0.5203
# 46      0.5275   -0.2358      0.4444   -0.1255      0.5990  ...      0.6511
# 47      0.4027    0.5190      0.3414   -0.1252      0.4637  ...      0.4778
# 48      0.3983    0.7638      0.3395   -0.2843      0.4513  ...      0.4884
# 49      0.3524   -0.5440      0.3010   -0.0493      0.4019  ...      0.4273
# 50      0.1986   -0.2583      0.1706    0.3499      0.2263  ...      0.2440
# 51      0.2004    0.2736      0.1686    0.5074      0.2287  ...      0.2471
# 52      0.4896    0.3180      0.4235   -0.2531      0.5449  ...      0.5744
# 53      0.3833    0.5445      0.3293    0.6565      0.4396  ...      0.4732
# 54      0.2029   -0.1788      0.1777    0.5962      0.2291  ...      0.2424
# 55      0.6909    1.2155      0.5732   -0.9531      0.7860  ...      0.8333
# 56      0.1756   -0.0435      0.1496    0.5641      0.2002  ...      0.2168
# 57      0.2508    0.3589      0.2159    0.2677      0.2880  ...      0.2986
# 58      0.2526    0.2570      0.2195    0.9348      0.2799  ...      0.2991
# 59      0.6361    1.1878      0.5560   -0.4824      0.7221  ...      0.7740
# 60      0.4845   -0.4887      0.4155   -0.2369      0.5432  ...      0.5717
# 61      0.3398    0.4254      0.2931    1.2991      0.3851  ...      0.4183
# 62      0.2687    0.4492      0.2291    0.3046      0.3114  ...      0.3263
# 63      0.2964   -0.2570      0.2478    0.1069      0.3416  ...      0.3667
# 64      0.6001    1.0419      0.5243   -0.4727      0.6780  ...      0.7068
# 65      0.2449    0.1714      0.2060    0.1381      0.2831  ...      0.2951
# 66      0.3879    0.0387      0.3339    0.5714      0.4400  ...      0.4779
# 67      0.2776    0.3738      0.2365    0.1618      0.3167  ...      0.3431
# 68      0.2783   -0.3561      0.2384    0.7143      0.3172  ...      0.3358
#
#     Overall_ESG_Exposure_coef  Overall_ESG_Exposure_stderr  \
# 33                     0.6969                       1.8496
# 34                     0.8032                       0.9989
# 35                    -3.4786                       1.7374
# 36                     0.1734                       0.5157
# 37                     0.0389                       0.1264
# 38                     1.1349                       5.3828
# 39                     3.8293                       4.8024
# 40                     3.1576                       2.2741
# 41                    -0.1048                       0.6077
# 42                     3.5388                       2.4422
# 43                    -0.3818                       0.2559
# 44                    -0.6361                       0.6403
# 45                     1.7755                       0.9475
# 46                    -0.8385                       1.6124
# 47                    -0.7210                       1.0337
# 48                    -0.2542                       0.6107
# 49                     1.2972                       5.4051
# 50                     1.0677                       1.6785
# 51                     0.0105                       0.0673
# 52                     0.5020                       1.3634
# 53                     0.0858                       0.1205
# 54                     0.5022                       0.4933
# 55                     0.8962                       1.0565
# 56                     0.3560                       0.2349
# 57                     0.3695                       0.4660
# 58                     0.3154                       0.4182
# 59                    -1.2376                       1.9459
# 60                   -18.8105                      12.4280
# 61                    -0.0317                       0.1093
# 62                    -0.9227                       1.3454
# 63                     0.1856                       0.2504
# 64                     0.2971                       0.3109
# 65                     1.0030                       1.2032
# 66                     1.4872                       1.6821
# 67                     0.1618                       0.5244
# 68                     0.1622                       0.4706
#
#     Overall_ESG_Sentiment_coef  Overall_ESG_Sentiment_stderr      R2  Adj_R2  \
# 33                     -0.0289                        0.0741  0.2618  0.1785
# 34                      0.0366                        0.1054  0.5728  0.5246
# 35                     -0.0459                        0.2152  0.3708  0.2998
# 36                     -0.0220                        0.0876  0.7704  0.7445
# 37                      0.0911                        0.1037  0.6767  0.6402
# 38                     -0.0851                        0.1155  0.0551 -0.0515
# 39                     -0.1437                        0.1359  0.6156  0.5722
# 40                     -0.0763                        0.0689  0.4511  0.3892
# 41                     -0.1366                        0.3563  0.4428  0.3799
# 42                     -0.1426                        0.1720  0.3637  0.2919
# 43                     -0.4056                        0.1827  0.6133  0.5697
# 44                      0.0067                        0.0882  0.4040  0.3367
# 45                     -0.2474                        0.0860  0.4200  0.3545
# 46                      0.0252                        0.1455  0.2822  0.2012
# 47                      0.1853                        0.1962  0.5659  0.5169
# 48                     -0.0652                        0.0889  0.2769  0.1953
# 49                     -0.0323                        0.0942  0.5667  0.5178
# 50                     -0.0431                        0.0557  0.4770  0.4179
# 51                     -0.1679                        0.1998  0.5000  0.4435
# 52                      0.0475                        0.0854  0.1990  0.1086
# 53                     -0.1408                        0.1004  0.6132  0.5695
# 54                     -0.0045                        0.0584  0.4999  0.4434
# 55                     -0.1482                        0.3353  0.5741  0.5261
# 56                     -0.1873                        0.1159  0.5094  0.4540
# 57                      0.2620                        0.3411  0.4449  0.3822
# 58                     -0.1317                        0.3934  0.6941  0.6595
# 59                     -0.4450                        0.2480  0.5989  0.5536
# 60                      0.2438                        0.2399  0.0876 -0.0154
# 61                      0.2054                        0.0797  0.6434  0.6032
# 62                      0.1600                        0.1480  0.4028  0.3353
# 63                      0.0613                        0.0984  0.6900  0.6550
# 64                     -0.3082                        0.2011  0.4550  0.3935
# 65                     -0.0666                        0.0737  0.2953  0.2158
# 66                     -0.0272                        0.1321  0.3659  0.2943
# 67                     -0.2229                        0.2643  0.5571  0.5071
# 68                     -0.0968                        0.0485  0.4894  0.4317
#
#     n_obs  Macro_Sector Ticker
# 33     70   Industrials   ABBV
# 34     70   Industrials    ABT
# 35     70   Industrials   ANET
# 36     70   Industrials    APH
# 37     70   Industrials   APTV
# 38     70   Industrials   BIIB
# 39     70   Industrials   BKNG
# 40     70   Industrials    BSX
# 41     70   Industrials     CF
# 42     70   Industrials   CHTR
# 43     70   Industrials    CMI
# 44     70   Industrials    DHR
# 45     70   Industrials     EL
# 46     70   Industrials   FTNT
# 47     70   Industrials     GM
# 48     70   Industrials    HII
# 49     70   Industrials   ISRG
# 50     70   Industrials    JNJ
# 51     70   Industrials     KO
# 52     70   Industrials     LW
# 53     70   Industrials   MCHP
# 54     70   Industrials   MDLZ
# 55     70   Industrials   NCLH
# 56     70   Industrials    PEP
# 57     70   Industrials     PM
# 58     70   Industrials    PPG
# 59     70   Industrials    RCL
# 60     70   Industrials   REGN
# 61     70   Industrials    SWK
# 62     70   Industrials      T
# 63     70   Industrials   TRMB
# 64     70   Industrials    UAL
# 65     70   Industrials     VZ
# 66     70   Industrials   XRAY
# 67     70   Industrials    XYL
# 68     70   Industrials    ZTS
#
# [36 rows x 21 columns]
#
# === Ticker-Level Regression: Consumer ===
#     const_coef  const_stderr  Mkt-RF_coef  Mkt-RF_stderr  SMB_coef  \
# 0       0.0151        0.0864       0.9586         0.2800    0.3226
# 1      -0.1122        0.0732       1.3712         0.1859   -0.7317
# 2       0.1250        0.0700       0.6580         0.1298    0.3912
# 3      -0.0392        0.1067       0.7890         0.1638   -0.3887
# 4      -0.0089        0.0400       1.4412         0.1971    0.0596
# 5       0.1261        0.0430       1.0933         0.1324   -0.3484
# 6      -0.0093        0.0211       1.0011         0.1550    0.1294
# 7      -0.0313        0.0332       0.7547         0.2354    0.9160
# 8       0.0236        0.0373       1.1499         0.1500   -0.1213
# 9      -0.3047        0.3031       1.2507         0.1644    0.4656
# 10      0.0003        0.0270       1.2633         0.1710   -0.1809
# 11      0.0328        0.0634       1.3966         0.2266    1.1824
# 12     -0.0020        0.0255       0.9218         0.1513    0.2844
# 13      0.0692        0.0615       0.8606         0.1472   -0.1284
# 14      0.0111        0.0500       1.7551         0.4320    1.6662
# 15      0.0186        0.0265       1.1612         0.1607    0.2732
# 16      0.0087        0.0538       1.0146         0.1736    0.0759
# 17     -0.0149        0.0314       0.8788         0.1848   -0.2560
# 18      0.0337        0.0221       0.5980         0.1182   -0.1962
# 19     -0.0320        0.1954       1.6119         0.2762    0.5097
#
#     SMB_stderr  HML_coef  HML_stderr  RMW_coef  RMW_stderr  ...  CMA_stderr  \
# 0       0.5320    0.8238      0.4895    0.4262      0.6366  ...      0.7103
# 1       0.3783   -0.1687      0.3256    0.0183      0.4299  ...      0.4542
# 2       0.2563   -0.0666      0.2203    0.4985      0.2918  ...      0.3055
# 3       0.3254   -0.5020      0.2801    0.2289      0.3706  ...      0.4023
# 4       0.3886    0.1614      0.3281    0.5093      0.4512  ...      0.4674
# 5       0.2638   -0.4086      0.2202   -0.1480      0.3043  ...      0.3262
# 6       0.3071    0.1032      0.2636    0.0425      0.3540  ...      0.3744
# 7       0.4669   -0.3501      0.3952    0.9707      0.5344  ...      0.5815
# 8       0.2997    0.6728      0.2547   -0.0751      0.3401  ...      0.3711
# 9       0.3308    0.0286      0.2755    0.4734      0.3730  ...      0.3897
# 10      0.3368    0.4403      0.2864   -0.4559      0.3891  ...      0.4043
# 11      0.4538   -0.2681      0.3963    0.6685      0.5100  ...      0.5505
# 12      0.3013    0.4173      0.2532   -0.0311      0.3460  ...      0.3724
# 13      0.2876    0.0204      0.2453    0.5111      0.3351  ...      0.3449
# 14      0.8373   -0.2311      0.7107    0.0034      0.9536  ...      1.0461
# 15      0.3151    0.4846      0.2638   -0.1960      0.3581  ...      0.3854
# 16      0.3486    0.0933      0.2891    0.2158      0.3985  ...      0.4235
# 17      0.3637   -0.4715      0.3123   -0.6631      0.4168  ...      0.4380
# 18      0.2286   -0.3575      0.1952    0.2454      0.2636  ...      0.2789
# 19      0.5590    0.7596      0.4832    0.4997      0.6286  ...      0.6774
#
#     Overall_ESG_Exposure_coef  Overall_ESG_Exposure_stderr  \
# 0                     -0.1655                       0.9889
# 1                      4.7442                       2.9962
# 2                     -2.7339                       3.4933
# 3                      2.6106                       5.8983
# 4                      0.3269                       0.8183
# 5                     -4.0214                       1.6032
# 6                      0.2655                       1.0179
# 7                      0.5316                       0.5418
# 8                     -0.4596                       0.9236
# 9                      8.3689                       9.8954
# 10                    -2.7534                       1.2372
# 11                    -0.8382                       1.2699
# 12                     0.4194                       0.7775
# 13                    -1.3314                       1.4326
# 14                     1.4558                       1.3865
# 15                    -1.8565                       1.7554
# 16                     0.2591                       2.1805
# 17                    -0.6386                       2.0147
# 18                     0.3212                       1.3144
# 19                     0.5733                       5.8637
#
#     Overall_ESG_Sentiment_coef  Overall_ESG_Sentiment_stderr      R2  Adj_R2  \
# 0                      -0.1297                        0.0827  0.3083  0.2429
# 1                       0.1101                        0.1561  0.5385  0.4864
# 2                      -0.2646                        0.1875  0.4423  0.3793
# 3                      -0.0243                        0.1730  0.3411  0.2668
# 4                      -0.0686                        0.0856  0.5444  0.4930
# 5                      -0.2575                        0.1566  0.6619  0.6237
# 6                      -0.0116                        0.0665  0.4917  0.4343
# 7                      -0.0374                        0.1538  0.2992  0.2201
# 8                       0.0337                        0.0760  0.6025  0.5577
# 9                       0.5028                        0.4722  0.6232  0.5807
# 10                      0.3297                        0.1540  0.5719  0.5235
# 11                     -0.0322                        0.0991  0.5530  0.5025
# 12                     -0.0562                        0.1325  0.5320  0.4792
# 13                     -0.0395                        0.0934  0.4420  0.3790
# 14                     -0.1321                        0.1198  0.4012  0.3336
# 15                     -0.0120                        0.0441  0.5993  0.5540
# 16                     -0.0360                        0.0587  0.4358  0.3721
# 17                      0.0982                        0.0864  0.3502  0.2768
# 18                     -0.1297                        0.1520  0.3698  0.2986
# 19                      0.0027                        0.1387  0.5142  0.4594
#
#     n_obs  Macro_Sector Ticker
# 0      82      Consumer    AAP
# 1      70      Consumer   ADBE
# 2      70      Consumer    ADP
# 3      70      Consumer   AKAM
# 4      70      Consumer    BBY
# 5      70      Consumer   CDNS
# 6      70      Consumer   CTSH
# 7      70      Consumer   DLTR
# 8      70      Consumer    HLT
# 9      70      Consumer    IQV
# 10     70      Consumer     IT
# 11     70      Consumer    KMX
# 12     70      Consumer    OMC
# 13     70      Consumer   ORLY
# 14     70      Consumer   PENN
# 15     70      Consumer    RHI
# 16     70      Consumer   ROST
# 17     70      Consumer   TTWO
# 18     70      Consumer    WMT
# 19     70      Consumer   WYNN
#
# [20 rows x 21 columns]
#
# === Ticker-Level Regression: Energy & Utilities ===
#     const_coef  const_stderr  Mkt-RF_coef  Mkt-RF_stderr  SMB_coef  \
# 20      0.0150        0.0513       0.5905         0.1400   -0.2982
# 21     -0.0475        0.0515       1.0694         0.2412    0.2075
# 22      0.0143        0.0169       1.4523         0.1874    0.1165
# 23     -0.0055        0.0401       0.5715         0.1497   -0.1349
# 24     -0.0016        0.0464       0.5438         0.1300   -0.1665
# 25      0.0130        0.0555       0.4359         0.1524    0.1288
# 26      0.0031        0.0286       0.5331         0.1181   -0.3662
# 27      0.0087        0.0247       0.5851         0.1331   -0.1311
# 28     -0.1168        0.0766       0.5131         0.1583   -0.0615
# 29     -0.0307        0.0328       0.8116         0.1157   -0.0580
# 30     -0.0361        0.0855       1.5644         0.2138    0.1039
# 31     -0.0143        0.0390       0.4711         0.1319   -0.3492
# 32     -0.3998        0.2400       1.1185         0.1604   -0.3420
#
#     SMB_stderr  HML_coef  HML_stderr  RMW_coef  RMW_stderr  ...  CMA_stderr  \
# 20      0.2779    0.1033      0.2362    0.1046      0.3158  ...      0.3398
# 21      0.4843    0.0436      0.4056   -0.2866      0.5489  ...      0.5971
# 22      0.3804   -0.4853      0.3315    0.3420      0.4239  ...      0.4598
# 23      0.2988    0.1638      0.2545    0.0469      0.3347  ...      0.3687
# 24      0.2546    0.1601      0.2199    0.4391      0.2867  ...      0.3148
# 25      0.3063    0.0979      0.2688    0.3929      0.3445  ...      0.3636
# 26      0.2332    0.2969      0.2001    0.0251      0.2658  ...      0.2837
# 27      0.2613    0.0470      0.2255    0.4157      0.2982  ...      0.3135
# 28      0.3234    0.1668      0.2765    0.5906      0.3650  ...      0.3907
# 29      0.2303    0.1600      0.1923    0.4181      0.2682  ...      0.2765
# 30      0.4249    1.6731      0.3572   -0.5069      0.4855  ...      0.5249
# 31      0.2604   -0.0327      0.2248    0.3938      0.2998  ...      0.3159
# 32      0.3121    0.7354      0.2644   -0.0211      0.3618  ...      0.3766
#
#     Overall_ESG_Exposure_coef  Overall_ESG_Exposure_stderr  \
# 20                    -0.3989                       0.4534
# 21                     0.2747                       0.2284
# 22                    12.5560                      19.1272
# 23                     0.0635                       0.0980
# 24                     0.0370                       0.1730
# 25                    -0.5009                       0.3916
# 26                    -0.0992                       0.1028
# 27                    -0.0414                       0.0772
# 28                     0.1157                       0.1413
# 29                     0.2589                       0.2098
# 30                     0.0000                       0.3043
# 31                     0.0227                       0.0565
# 32                     0.9861                       0.6314
#
#     Overall_ESG_Sentiment_coef  Overall_ESG_Sentiment_stderr      R2  Adj_R2  \
# 20                      0.3290                        0.3244  0.2797  0.1983
# 21                     -0.4668                        0.2857  0.3383  0.2636
# 22                     -0.3882                        0.5054  0.5691  0.5204
# 23                     -0.0643                        0.1635  0.2547  0.1706
# 24                     -0.0562                        0.1295  0.3570  0.2845
# 25                      0.3245                        0.1676  0.2414  0.1558
# 26                      0.0884                        0.0655  0.3824  0.3127
# 27                      0.0293                        0.0604  0.3223  0.2458
# 28                      0.4066                        0.2556  0.2664  0.1836
# 29                     -0.1623                        0.1473  0.5454  0.4941
# 30                      0.1476                        0.2407  0.7052  0.6719
# 31                     -0.0154                        0.1295  0.2748  0.1930
# 32                      0.3728                        0.2063  0.5631  0.5138
#
#     n_obs        Macro_Sector Ticker
# 20     70  Energy & Utilities    AEP
# 21     70  Energy & Utilities    AES
# 22     70  Energy & Utilities    EFX
# 23     70  Energy & Utilities   EVRG
# 24     70  Energy & Utilities    EXC
# 25     70  Energy & Utilities     FE
# 26     70  Energy & Utilities     NI
# 27     70  Energy & Utilities    PEG
# 28     70  Energy & Utilities    PNW
# 29     70  Energy & Utilities    PPL
# 30     70  Energy & Utilities    SLB
# 31     70  Energy & Utilities    WEC
# 32     70  Energy & Utilities    WMB
#
# [13 rows x 21 columns]
#
# Done! All tables printed.

# %%
import pandas as pd
import statsmodels.api as sm

# Load your data from Excel
df = pd.read_excel(
    'climate_final_with_ff5_and_excess_return.xlsx',
    sheet_name='climate_final_with_ff5_and_exce',
    parse_dates=['date']
)

# Define your factor lists
fama_french_factors = ['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA']
env_factors = ['Overall_ESG_Exposure', 'Overall_ESG_Sentiment']

# Helper function to run regressions and collect results
def run_regression(y, X):
    X = sm.add_constant(X)
    model = sm.OLS(y, X).fit()
    results = {}
    for var in X.columns:
        results[f'{var}_coef']   = model.params[var]
        results[f'{var}_tstat']  = model.tvalues[var]
        results[f'{var}_stderr'] = model.bse[var]
    results['R2']     = model.rsquared
    results['Adj_R2'] = model.rsquared_adj
    return results

# --- 1. Macro‐Sector Level Regressions ---
sector_results_fama     = []
sector_results_fama_env = []

for sector, group in df.groupby('Macro_Sector'):
    # Fama‐French only
    res_fama = run_regression(group['excess_RET'], group[fama_french_factors])
    res_fama['Macro_Sector'] = sector
    sector_results_fama.append(res_fama)
    # Fama‐French + ENV
    res_fama_env = run_regression(
        group['excess_RET'],
        group[fama_french_factors + env_factors]
    )
    res_fama_env['Macro_Sector'] = sector
    sector_results_fama_env.append(res_fama_env)

sector_df_fama     = pd.DataFrame(sector_results_fama)
sector_df_fama_env = pd.DataFrame(sector_results_fama_env)

# --- 2. Ticker‐Level Regressions (within each Macro Sector) ---
ticker_results_fama     = []
ticker_results_fama_env = []

for (sector, ticker), group in df.groupby(['Macro_Sector', 'TICKER']):
    # Fama‐French only
    res_t_fama = run_regression(group['excess_RET'], group[fama_french_factors])
    res_t_fama['Macro_Sector'] = sector
    res_t_fama['Ticker']       = ticker
    ticker_results_fama.append(res_t_fama)
    # Fama‐French + ENV
    res_t_fama_env = run_regression(
        group['excess_RET'],
        group[fama_french_factors + env_factors]
    )
    res_t_fama_env['Macro_Sector'] = sector
    res_t_fama_env['Ticker']       = ticker
    ticker_results_fama_env.append(res_t_fama_env)

ticker_df_fama     = pd.DataFrame(ticker_results_fama)
ticker_df_fama_env = pd.DataFrame(ticker_results_fama_env)

# --- 3. Pretty‐printing ---
print("\n=== Macro‐Sector Level: FF5 Only ===")
print(sector_df_fama.round(4))

print("\n=== Macro‐Sector Level: FF5 + ENV ===")
print(sector_df_fama_env.round(4))

for name, df_t in [
    ("Industrials", ticker_df_fama[ticker_df_fama['Macro_Sector']=='Industrials']),
    ("Consumer",    ticker_df_fama[ticker_df_fama['Macro_Sector']=='Consumer']),
    ("Energy & Utilities", ticker_df_fama[ticker_df_fama['Macro_Sector']=='Energy & Utilities'])
]:
    print(f"\n=== Ticker‐Level ({name}): FF5 Only ===")
    print(df_t.round(4))

for name, df_t in [
    ("Industrials", ticker_df_fama_env[ticker_df_fama_env['Macro_Sector']=='Industrials']),
    ("Consumer",    ticker_df_fama_env[ticker_df_fama_env['Macro_Sector']=='Consumer']),
    ("Energy & Utilities", ticker_df_fama_env[ticker_df_fama_env['Macro_Sector']=='Energy & Utilities'])
]:
    print(f"\n=== Ticker‐Level ({name}): FF5 + ENV ===")
    print(df_t.round(4))

print("\nDone! All tables printed.")
# Out:
# === Macro‐Sector Level: FF5 Only ===
#    const_coef  const_tstat  const_stderr  Mkt-RF_coef  Mkt-RF_tstat  \
# 0     -0.0034      -1.4755        0.0023       1.0880       22.7770
# 1     -0.0033      -1.3986        0.0023       0.7781       16.1851
# 2     -0.0028      -1.6424        0.0017       0.9543       27.3059
#
#    Mkt-RF_stderr  SMB_coef  SMB_tstat  SMB_stderr  HML_coef  ...  HML_stderr  \
# 0         0.0478    0.2473     2.6322      0.0939    0.0279  ...      0.0793
# 1         0.0481   -0.1016    -1.0700      0.0949    0.2424  ...      0.0797
# 2         0.0349    0.1912     2.7711      0.0690    0.1192  ...      0.0579
#
#    RMW_coef  RMW_tstat  RMW_stderr  CMA_coef  CMA_tstat  CMA_stderr      R2  \
# 0    0.2349     2.1803      0.1078   -0.0072    -0.0639      0.1126  0.3478
# 1    0.1790     1.6497      0.1085    0.3939     3.4795      0.1132  0.2976
# 2    0.2319     2.9392      0.0789    0.1330     1.6157      0.0823  0.3019
#
#    Adj_R2        Macro_Sector
# 0  0.3455            Consumer
# 1  0.2937  Energy & Utilities
# 2  0.3005         Industrials
#
# [3 rows x 21 columns]
#
# === Macro‐Sector Level: FF5 + ENV ===
#    const_coef  const_tstat  const_stderr  Mkt-RF_coef  Mkt-RF_tstat  \
# 0      0.0032       0.5697        0.0056       1.0891       22.7940
# 1     -0.0043      -0.6139        0.0070       0.7790       16.1943
# 2      0.0010       0.2788        0.0035       0.9554       27.3364
#
#    Mkt-RF_stderr  SMB_coef  SMB_tstat  SMB_stderr  HML_coef  ...  CMA_stderr  \
# 0         0.0478    0.2452     2.6090      0.0940    0.0284  ...      0.1127
# 1         0.0481   -0.0974    -1.0245      0.0951    0.2354  ...      0.1135
# 2         0.0350    0.1875     2.7178      0.0690    0.1218  ...      0.0824
#
#    Overall_ESG_Exposure_coef  Overall_ESG_Exposure_tstat  \
# 0                    -0.1212                     -1.1132
# 1                    -0.0096                     -0.6000
# 2                     0.0117                      0.6152
#
#    Overall_ESG_Exposure_stderr  Overall_ESG_Sentiment_coef  \
# 0                       0.1089                     -0.0124
# 1                       0.0160                      0.0173
# 2                       0.0190                     -0.0174
#
#    Overall_ESG_Sentiment_tstat  Overall_ESG_Sentiment_stderr      R2  Adj_R2  \
# 0                      -0.8517                        0.0146  0.3487  0.3454
# 1                       0.8047                        0.0215  0.2985  0.2931
# 2                      -1.7067                        0.0102  0.3029  0.3009
#
#          Macro_Sector
# 0            Consumer
# 1  Energy & Utilities
# 2         Industrials
#
# [3 rows x 27 columns]
#
# === Ticker‐Level (Industrials): FF5 Only ===
#     const_coef  const_tstat  const_stderr  Mkt-RF_coef  Mkt-RF_tstat  \
# 33      0.0077       0.9729        0.0079       0.5335        3.2703
# 34     -0.0043      -0.8403        0.0051       0.8567        8.1612
# 35      0.0131       1.0710        0.0123       1.2030        4.7532
# 36      0.0023       0.4797        0.0047       1.1470       11.7855
# 37     -0.0195      -2.0399        0.0096       1.4773        7.4858
# 38     -0.0080      -0.6347        0.0127      -0.0284       -0.1085
# 39      0.0042       0.5374        0.0079       1.3599        8.3553
# 40      0.0014       0.2168        0.0063       0.8299        6.4302
# 41      0.0084       0.7988        0.0106       0.9856        4.5183
# 42     -0.0095      -0.8796        0.0108       0.8567        3.8256
# 43      0.0053       0.8107        0.0065       1.0056        7.4448
# 44      0.0008       0.1053        0.0072       0.7915        5.3520
# 45     -0.0212      -1.9913        0.0107       0.8442        3.8334
# 46      0.0177       1.4113        0.0126       1.0551        4.0717
# 47     -0.0021      -0.2177        0.0098       1.3099        6.4883
# 48     -0.0011      -0.1115        0.0094       0.5051        2.5966
# 49     -0.0005      -0.0579        0.0084       1.5108        8.7157
# 50     -0.0066      -1.4080        0.0047       0.5872        6.0449
# 51     -0.0035      -0.7298        0.0048       0.5790        5.8006
# 52     -0.0025      -0.2218        0.0114       0.7253        3.0796
# 53     -0.0076      -0.8122        0.0094       1.3415        6.9230
# 54     -0.0062      -1.2832        0.0049       0.5919        5.8909
# 55     -0.0085      -0.5202        0.0164       2.2891        6.7758
# 56     -0.0043      -1.0063        0.0042       0.5185        5.9225
# 57      0.0013       0.2187        0.0061       0.5896        4.6984
# 58     -0.0135      -2.2339        0.0060       1.1108        8.9312
# 59      0.0069       0.4458        0.0154       2.2482        7.0788
# 60      0.0063       0.5429        0.0115       0.2456        1.0303
# 61     -0.0162      -1.8261        0.0089       1.0015        5.4635
# 62     -0.0039      -0.5945        0.0066       0.6113        4.4799
# 63     -0.0034      -0.4869        0.0071       1.3435        9.1884
# 64      0.0021       0.1473        0.0143       1.2659        4.2763
# 65     -0.0085      -1.4423        0.0059       0.5257        4.3066
# 66     -0.0191      -2.0457        0.0093       0.7931        4.1144
# 67     -0.0046      -0.6890        0.0067       1.0269        7.3891
# 68     -0.0026      -0.3857        0.0068       0.7154        5.0766
#
#     Mkt-RF_stderr  SMB_coef  SMB_tstat  SMB_stderr  HML_coef  ...  RMW_coef  \
# 33         0.1631    0.3315     1.0292      0.3221   -0.0737  ...    0.4500
# 34         0.1050    0.0185     0.0893      0.2072   -0.5639  ...    0.0722
# 35         0.2531   -0.5050    -1.0106      0.4997   -0.5532  ...    0.4042
# 36         0.0973    0.0678     0.3527      0.1921    0.2449  ...    0.4770
# 37         0.1974    1.3933     3.5761      0.3896   -0.0440  ...    1.4563
# 38         0.2615    0.6116     1.1847      0.5162   -0.6232  ...    0.1681
# 39         0.1628   -0.3326    -1.0351      0.3213    0.6259  ...   -0.2404
# 40         0.1291   -0.5624    -2.2073      0.2548    0.1718  ...   -0.0665
# 41         0.2181    0.5210     1.2099      0.4306    0.5427  ...   -0.3367
# 42         0.2239    0.6947     1.5714      0.4421   -0.0163  ...    0.8273
# 43         0.1351    0.1058     0.3968      0.2667    0.4517  ...   -0.1546
# 44         0.1479    0.0564     0.1932      0.2920   -0.3396  ...    0.2300
# 45         0.2202    0.8874     2.0411      0.4347   -0.5632  ...    1.2253
# 46         0.2591    0.1359     0.2656      0.5116   -0.2881  ...   -0.0810
# 47         0.2019    0.6213     1.5587      0.3986    0.4329  ...   -0.1024
# 48         0.1945    0.1587     0.4131      0.3840    0.7349  ...   -0.2212
# 49         0.1733   -0.5282    -1.5433      0.3422   -0.5111  ...   -0.0878
# 50         0.0971    0.1144     0.5966      0.1918   -0.2948  ...    0.3659
# 51         0.0998   -0.3021    -1.5330      0.1971    0.2230  ...    0.5115
# 52         0.2355    0.1345     0.2893      0.4649    0.2839  ...   -0.2054
# 53         0.1938    0.5973     1.5613      0.3826    0.3940  ...    0.7194
# 54         0.1005   -0.1639    -0.8262      0.1984   -0.2284  ...    0.5793
# 55         0.3378    0.4526     0.6786      0.6670    1.2590  ...   -1.1105
# 56         0.0875   -0.0547    -0.3166      0.1728   -0.1194  ...    0.5724
# 57         0.1255   -0.0083    -0.0335      0.2478    0.3394  ...    0.2522
# 58         0.1244    0.1897     0.7724      0.2455    0.1880  ...    0.9387
# 59         0.3176    0.1133     0.1807      0.6270    1.3991  ...   -0.7054
# 60         0.2384   -0.0205    -0.0435      0.4706   -0.5223  ...   -0.0816
# 61         0.1833    0.9484     2.6208      0.3619    0.3486  ...    1.0607
# 62         0.1365   -0.2880    -1.0690      0.2694    0.3887  ...    0.2258
# 63         0.1462    0.6662     2.3080      0.2887   -0.2477  ...    0.1620
# 64         0.2960    0.3870     0.6623      0.5844    1.3106  ...   -0.6010
# 65         0.1221   -0.5097    -2.1150      0.2410    0.1686  ...    0.0472
# 66         0.1928    0.6551     1.7214      0.3805   -0.0566  ...    0.6145
# 67         0.1390   -0.1765    -0.6435      0.2744    0.3101  ...    0.2116
# 68         0.1409    0.4723     1.6976      0.2782   -0.4795  ...    0.7708
#
#     RMW_tstat  RMW_stderr  CMA_coef  CMA_tstat  CMA_stderr      R2  Adj_R2  \
# 33     1.2218      0.3683    0.6825     1.7764      0.3842  0.2590  0.2011
# 34     0.3048      0.2370    1.1573     4.6818      0.2472  0.5603  0.5259
# 35     0.7075      0.5714    0.3331     0.5588      0.5960  0.3168  0.2634
# 36     2.1708      0.2197   -0.3580    -1.5618      0.2292  0.7689  0.7508
# 37     3.2687      0.4455   -0.3121    -0.6716      0.4647  0.6727  0.6471
# 38     0.2849      0.5903    0.5283     0.8580      0.6157  0.0383 -0.0368
# 39    -0.6543      0.3674   -0.2362    -0.6162      0.3833  0.5948  0.5632
# 40    -0.2281      0.2913    0.0896     0.2948      0.3039  0.4160  0.3703
# 41    -0.6837      0.4924    0.6258     1.2184      0.5137  0.4411  0.3974
# 42     1.6365      0.5055    0.0056     0.0106      0.5273  0.3286  0.2762
# 43    -0.5069      0.3049    0.0989     0.3110      0.3181  0.5823  0.5497
# 44     0.6890      0.3339    0.1023     0.2939      0.3483  0.3793  0.3308
# 45     2.4647      0.4971    0.3666     0.7069      0.5186  0.3409  0.2894
# 46    -0.1384      0.5850   -0.2174    -0.3562      0.6102  0.2782  0.2219
# 47    -0.2247      0.4558   -0.0174    -0.0366      0.4754  0.5527  0.5177
# 48    -0.5038      0.4391   -0.3684    -0.8041      0.4581  0.2698  0.2127
# 49    -0.2244      0.3913    0.7174     1.7575      0.4082  0.5643  0.5302
# 50     1.6685      0.2193    0.9281     4.0569      0.2288  0.4719  0.4306
# 51     2.2701      0.2253    0.1815     0.7720      0.2350  0.4803  0.4397
# 52    -0.3864      0.5317    0.0442     0.0797      0.5546  0.1943  0.1313
# 53     1.6444      0.4374   -0.4303    -0.9430      0.4563  0.5899  0.5579
# 54     2.5538      0.2268    0.8879     3.7523      0.2366  0.4913  0.4515
# 55    -1.4561      0.7627   -0.4873    -0.6125      0.7956  0.5674  0.5336
# 56     2.8959      0.1976    0.5244     2.5436      0.2062  0.4826  0.4422
# 57     0.8903      0.2833    0.5140     1.7393      0.2955  0.4364  0.3924
# 58     3.3433      0.2808   -0.1332    -0.4547      0.2929  0.6802  0.6552
# 59    -0.9839      0.7170   -0.9204    -1.2307      0.7479  0.5766  0.5435
# 60    -0.1517      0.5381    0.5076     0.9043      0.5613  0.0473 -0.0272
# 61     2.5634      0.4138   -0.1345    -0.3117      0.4316  0.5613  0.5270
# 62     0.7329      0.3080    0.4334     1.3489      0.3213  0.3796  0.3312
# 63     0.4909      0.3301   -0.1451    -0.4215      0.3443  0.6869  0.6624
# 64    -0.8994      0.6683   -0.5483    -0.7866      0.6971  0.4321  0.3877
# 65     0.1713      0.2756    0.2144     0.7460      0.2874  0.2715  0.2145
# 66     1.4123      0.4351    0.5454     1.2016      0.4539  0.3542  0.3037
# 67     0.6745      0.3137   -0.3358    -1.0260      0.3273  0.5430  0.5073
# 68     2.4227      0.3182   -0.0573    -0.1726      0.3319  0.4564  0.4140
#
#     Macro_Sector  Ticker
# 33   Industrials    ABBV
# 34   Industrials     ABT
# 35   Industrials    ANET
# 36   Industrials     APH
# 37   Industrials    APTV
# 38   Industrials    BIIB
# 39   Industrials    BKNG
# 40   Industrials     BSX
# 41   Industrials      CF
# 42   Industrials    CHTR
# 43   Industrials     CMI
# 44   Industrials     DHR
# 45   Industrials      EL
# 46   Industrials    FTNT
# 47   Industrials      GM
# 48   Industrials     HII
# 49   Industrials    ISRG
# 50   Industrials     JNJ
# 51   Industrials      KO
# 52   Industrials      LW
# 53   Industrials    MCHP
# 54   Industrials    MDLZ
# 55   Industrials    NCLH
# 56   Industrials     PEP
# 57   Industrials      PM
# 58   Industrials     PPG
# 59   Industrials     RCL
# 60   Industrials    REGN
# 61   Industrials     SWK
# 62   Industrials       T
# 63   Industrials    TRMB
# 64   Industrials     UAL
# 65   Industrials      VZ
# 66   Industrials    XRAY
# 67   Industrials     XYL
# 68   Industrials     ZTS
#
# [36 rows x 22 columns]
#
# === Ticker‐Level (Consumer): FF5 Only ===
#     const_coef  const_tstat  const_stderr  Mkt-RF_coef  Mkt-RF_tstat  \
# 0      -0.0220      -1.6720        0.0131       0.9624        3.4305
# 1      -0.0071      -0.7856        0.0090       1.3625        7.3127
# 2       0.0019       0.3013        0.0063       0.6385        4.9132
# 3      -0.0066      -0.8529        0.0077       0.8056        5.0482
# 4      -0.0088      -0.9328        0.0094       1.4468        7.4436
# 5       0.0129       1.9561        0.0066       1.0531        7.7156
# 6      -0.0073      -0.9954        0.0073       1.0004        6.6033
# 7      -0.0128      -1.1372        0.0113       0.7562        3.2527
# 8       0.0060       0.8419        0.0072       1.1476        7.7644
# 9      -0.0084      -1.0749        0.0078       1.2507        7.7502
# 10      0.0086       1.0003        0.0086       1.1961        6.7704
# 11     -0.0069      -0.6415        0.0108       1.4028        6.2899
# 12     -0.0027      -0.3756        0.0072       0.9139        6.1582
# 13      0.0041       0.5827        0.0070       0.8438        5.8465
# 14     -0.0021      -0.1047        0.0204       1.7546        4.1712
# 15     -0.0059      -0.7788        0.0076       1.1412        7.2879
# 16     -0.0032      -0.3872        0.0082       1.0226        6.0061
# 17      0.0050       0.5637        0.0089       0.8947        4.8966
# 18      0.0064       1.1367        0.0056       0.6098        5.2867
# 19     -0.0150      -1.1374        0.0132       1.6127        5.9373
#
#     Mkt-RF_stderr  SMB_coef  SMB_tstat  SMB_stderr  HML_coef  ...  RMW_coef  \
# 0          0.2805    0.5160     0.9938      0.5192    0.6401  ...    0.6152
# 1          0.1863   -0.5873    -1.5967      0.3678   -0.2716  ...    0.1533
# 2          0.1300    0.3373     1.3147      0.2566    0.0184  ...    0.5227
# 3          0.1596   -0.3907    -1.2401      0.3151   -0.5384  ...    0.1908
# 4          0.1944    0.0534     0.1392      0.3837    0.1390  ...    0.4563
# 5          0.1365   -0.2162    -0.8022      0.2695   -0.4699  ...   -0.0039
# 6          0.1515    0.1171     0.3917      0.2991    0.1146  ...    0.0280
# 7          0.2325    0.9583     2.0879      0.4590   -0.4207  ...    0.9724
# 8          0.1478   -0.1377    -0.4718      0.2918    0.6948  ...   -0.0771
# 9          0.1614    0.5708     1.7917      0.3186   -0.0512  ...    0.5697
# 10         0.1767   -0.0831    -0.2382      0.3488    0.5073  ...   -0.2363
# 11         0.2230    1.1918     2.7068      0.4403   -0.2772  ...    0.6729
# 12         0.1484    0.2665     0.9095      0.2930    0.4286  ...   -0.0679
# 13         0.1443   -0.1103    -0.3870      0.2849    0.0560  ...    0.5797
# 14         0.4206    1.7748     2.1371      0.8305   -0.3875  ...    0.0775
# 15         0.1566    0.3233     1.0457      0.3091    0.4569  ...   -0.1546
# 16         0.1703    0.0619     0.1843      0.3361    0.0830  ...    0.1933
# 17         0.1827   -0.2251    -0.6239      0.3607   -0.5243  ...   -0.6463
# 18         0.1153   -0.2106    -0.9247      0.2277   -0.3640  ...    0.2023
# 19         0.2716    0.5188     0.9674      0.5363    0.7469  ...    0.4996
#
#     RMW_tstat  RMW_stderr  CMA_coef  CMA_tstat  CMA_stderr      R2  Adj_R2  \
# 0      0.9844      0.6249    0.1071     0.1587      0.6752  0.2850  0.2379
# 1      0.3646      0.4206   -0.2097    -0.4779      0.4388  0.5194  0.4818
# 2      1.7818      0.2934   -0.0928    -0.3033      0.3060  0.4143  0.3685
# 3      0.5296      0.3603    0.8657     2.3035      0.3758  0.3363  0.2844
# 4      1.0398      0.4388    0.1948     0.4256      0.4577  0.5397  0.5038
# 5     -0.0127      0.3081   -0.5257    -1.6356      0.3214  0.6227  0.5932
# 6      0.0819      0.3420   -0.1463    -0.4100      0.3568  0.4911  0.4513
# 7      1.8528      0.5248    0.8955     1.6358      0.5474  0.2882  0.2325
# 8     -0.2312      0.3337   -0.5805    -1.6677      0.3481  0.6009  0.5697
# 9      1.5639      0.3643   -0.1916    -0.5042      0.3800  0.6132  0.5829
# 10    -0.5925      0.3988   -0.5253    -1.2626      0.4160  0.5162  0.4784
# 11     1.3366      0.5035    0.0327     0.0623      0.5252  0.5498  0.5147
# 12    -0.2025      0.3350    0.3417     0.9777      0.3495  0.5293  0.4925
# 13     1.7793      0.3258    0.1302     0.3832      0.3399  0.4317  0.3873
# 14     0.0816      0.9496   -0.2571    -0.2596      0.9906  0.3839  0.3358
# 15    -0.4373      0.3535   -0.2770    -0.7512      0.3687  0.5919  0.5601
# 16     0.5030      0.3844    0.0023     0.0056      0.4009  0.4323  0.3880
# 17    -1.5669      0.4125    0.3509     0.8155      0.4303  0.3364  0.2846
# 18     0.7770      0.2604    0.4496     1.6552      0.2716  0.3531  0.3026
# 19     0.8148      0.6132   -0.7670    -1.1990      0.6396  0.5141  0.4762
#
#     Macro_Sector  Ticker
# 0       Consumer     AAP
# 1       Consumer    ADBE
# 2       Consumer     ADP
# 3       Consumer    AKAM
# 4       Consumer     BBY
# 5       Consumer    CDNS
# 6       Consumer    CTSH
# 7       Consumer    DLTR
# 8       Consumer     HLT
# 9       Consumer     IQV
# 10      Consumer      IT
# 11      Consumer     KMX
# 12      Consumer     OMC
# 13      Consumer    ORLY
# 14      Consumer    PENN
# 15      Consumer     RHI
# 16      Consumer    ROST
# 17      Consumer    TTWO
# 18      Consumer     WMT
# 19      Consumer    WYNN
#
# [20 rows x 22 columns]
#
# === Ticker‐Level (Energy & Utilities): FF5 Only ===
#     const_coef  const_tstat  const_stderr  Mkt-RF_coef  Mkt-RF_tstat  \
# 20     -0.0032      -0.4823        0.0066       0.5653        4.1319
# 21     -0.0078      -0.6717        0.0116       1.0513        4.3747
# 22     -0.0021      -0.2375        0.0090       1.4406        7.7466
# 23     -0.0026      -0.3672        0.0071       0.5871        4.0260
# 24     -0.0052      -0.8531        0.0061       0.5332        4.2640
# 25     -0.0034      -0.4594        0.0074       0.4101        2.6725
# 26     -0.0003      -0.0480        0.0057       0.5517        4.6970
# 27     -0.0015      -0.2394        0.0063       0.5805        4.4870
# 28     -0.0063      -0.8176        0.0077       0.4977        3.1378
# 29     -0.0073      -1.3043        0.0056       0.8138        7.0640
# 30     -0.0043      -0.4248        0.0102       1.5386        7.3064
# 31     -0.0035      -0.5544        0.0063       0.4736        3.6513
# 32      0.0051       0.6685        0.0077       1.0719        6.7522
#
#     Mkt-RF_stderr  SMB_coef  SMB_tstat  SMB_stderr  HML_coef  ...  RMW_coef  \
# 20         0.1368   -0.3172    -1.1742      0.2701    0.1429  ...    0.1011
# 21         0.2403    0.3465     0.7303      0.4744   -0.0963  ...   -0.1918
# 22         0.1860    0.1185     0.3229      0.3671   -0.4705  ...    0.3744
# 23         0.1458   -0.1278    -0.4438      0.2879    0.1422  ...    0.0662
# 24         0.1251   -0.1545    -0.6259      0.2469    0.1551  ...    0.4423
# 25         0.1534   -0.0012    -0.0040      0.3029    0.2807  ...    0.3809
# 26         0.1175   -0.4235    -1.8265      0.2319    0.3376  ...   -0.0067
# 27         0.1294   -0.1390    -0.5444      0.2554    0.0716  ...    0.4230
# 28         0.1586   -0.0945    -0.3017      0.3132    0.1627  ...    0.4731
# 29         0.1152   -0.0959    -0.4215      0.2274    0.1622  ...    0.3413
# 30         0.2106    0.1825     0.4389      0.4157    1.6363  ...   -0.4144
# 31         0.1297   -0.3285    -1.2829      0.2561   -0.0753  ...    0.3801
# 32         0.1587   -0.2856    -0.9113      0.3134    0.7018  ...   -0.0418
#
#     RMW_tstat  RMW_stderr  CMA_coef  CMA_tstat  CMA_stderr      R2  Adj_R2  \
# 20     0.3273      0.3089    0.4340     1.3469      0.3222  0.2673  0.2101
# 21    -0.3536      0.5425    1.0256     1.8123      0.5659  0.3098  0.2558
# 22     0.8919      0.4198    0.0786     0.1796      0.4379  0.5598  0.5254
# 23     0.2011      0.3292    0.2666     0.7763      0.3434  0.2479  0.1891
# 24     1.5667      0.2823    0.4913     1.6683      0.2945  0.3550  0.3047
# 25     1.0996      0.3464   -0.0770    -0.2131      0.3613  0.1955  0.1326
# 26    -0.0252      0.2652    0.3491     1.2622      0.2766  0.3552  0.3048
# 27     1.4481      0.2921    0.2746     0.9013      0.3047  0.3187  0.2655
# 28     1.3210      0.3581    0.3846     1.0297      0.3735  0.2357  0.1760
# 29     1.3124      0.2601    0.5077     1.8715      0.2713  0.5340  0.4976
# 30    -0.8717      0.4754    0.4850     0.9780      0.4959  0.6994  0.6759
# 31     1.2979      0.2928    0.5984     1.9592      0.3054  0.2682  0.2110
# 32    -0.1168      0.3584    0.3024     0.8089      0.3738  0.5398  0.5038
#
#           Macro_Sector  Ticker
# 20  Energy & Utilities     AEP
# 21  Energy & Utilities     AES
# 22  Energy & Utilities     EFX
# 23  Energy & Utilities    EVRG
# 24  Energy & Utilities     EXC
# 25  Energy & Utilities      FE
# 26  Energy & Utilities      NI
# 27  Energy & Utilities     PEG
# 28  Energy & Utilities     PNW
# 29  Energy & Utilities     PPL
# 30  Energy & Utilities     SLB
# 31  Energy & Utilities     WEC
# 32  Energy & Utilities     WMB
#
# [13 rows x 22 columns]
#
# === Ticker‐Level (Industrials): FF5 + ENV ===
#     const_coef  const_tstat  const_stderr  Mkt-RF_coef  Mkt-RF_tstat  \
# 33      0.0102       0.2833        0.0361       0.5299        3.1539
# 34     -0.0447      -1.0647        0.0420       0.8285        7.7314
# 35      0.0699       1.5902        0.0440       1.2619        5.0386
# 36      0.0024       0.0452        0.0521       1.1519       11.6496
# 37     -0.0398      -1.2924        0.0308       1.4432        7.0912
# 38     -0.0108      -0.3095        0.0350      -0.0078       -0.0296
# 39      0.0071       0.1181        0.0599       1.3672        8.3619
# 40     -0.0715      -0.9343        0.0766       0.8521        6.6248
# 41      0.0792       0.3420        0.2315       0.9828        4.4287
# 42     -0.0084      -0.1112        0.0751       0.8133        3.6449
# 43      0.0642       1.7487        0.0367       1.0060        7.4629
# 44      0.0133       1.1026        0.0121       0.7901        5.3315
# 45     -0.0062      -0.4119        0.0151       0.8505        4.0490
# 46      0.0237       0.9011        0.0263       1.0457        3.8948
# 47      0.0293       0.2008        0.1461       1.2856        6.3367
# 48      0.0412       0.6700        0.0614       0.5267        2.6333
# 49     -0.0092      -0.1192        0.0772       1.5137        8.4913
# 50     -0.0093      -0.6696        0.0138       0.5867        5.8909
# 51      0.0283       0.5179        0.0546       0.5749        5.7477
# 52     -0.0518      -0.5743        0.0901       0.7444        3.0731
# 53     -0.0023      -0.1405        0.0166       1.3390        6.9135
# 54     -0.0422      -1.1716        0.0360       0.5969        5.7889
# 55     -0.0222      -0.3846        0.0577       2.2482        6.5486
# 56      0.0029       0.1186        0.0241       0.5275        6.0467
# 57     -0.1345      -0.8814        0.1526       0.5666        4.3919
# 58     -0.0157      -0.0724        0.2162       1.0892        8.7654
# 59      0.2223       1.2556        0.1770       2.2396        7.0578
# 60      0.0485       1.1270        0.0430       0.2993        1.2491
# 61     -0.0499      -3.9146        0.0127       0.9117        5.3756
# 62     -0.0187      -1.5979        0.0117       0.5776        4.1933
# 63     -0.0177      -0.8976        0.0197       1.3443        8.9950
# 64      0.0544       1.4902        0.0365       1.3092        4.4226
# 65     -0.0112      -0.2885        0.0388       0.5091        4.1471
# 66     -0.0520      -0.6589        0.0788       0.7683        3.8852
# 67      0.0048       0.1164        0.0410       1.0283        7.3812
# 68      0.0317       0.8818        0.0359       0.6923        4.9704
#
#     Mkt-RF_stderr  SMB_coef  SMB_tstat  SMB_stderr  HML_coef  ...  \
# 33         0.1680    0.3037     0.9131      0.3326   -0.0369  ...
# 34         0.1072    0.0037     0.0176      0.2129   -0.5300  ...
# 35         0.2504   -0.4179    -0.8495      0.4919   -0.8003  ...
# 36         0.0989    0.0958     0.4801      0.1996    0.2171  ...
# 37         0.2035    1.3633     3.4400      0.3963    0.0242  ...
# 38         0.2643    0.5252     0.9721      0.5403   -0.5641  ...
# 39         0.1635   -0.2666    -0.8327      0.3202    0.5819  ...
# 40         0.1286   -0.4569    -1.7792      0.2568    0.0165  ...
# 41         0.2219    0.5453     1.2381      0.4404    0.5069  ...
# 42         0.2231    0.6086     1.3796      0.4411    0.1960  ...
# 43         0.1348    0.1536     0.5874      0.2616    0.4579  ...
# 44         0.1482   -0.0121    -0.0413      0.2942   -0.2427  ...
# 45         0.2100    0.7601     1.7931      0.4239   -0.4055  ...
# 46         0.2685    0.0884     0.1677      0.5275   -0.2358  ...
# 47         0.2029    0.5641     1.4009      0.4027    0.5190  ...
# 48         0.2000    0.0954     0.2394      0.3983    0.7638  ...
# 49         0.1783   -0.4930    -1.3989      0.3524   -0.5440  ...
# 50         0.0996    0.0837     0.4213      0.1986   -0.2583  ...
# 51         0.1000   -0.3319    -1.6564      0.2004    0.2736  ...
# 52         0.2422    0.0668     0.1364      0.4896    0.3180  ...
# 53         0.1937    0.4767     1.2436      0.3833    0.5445  ...
# 54         0.1031   -0.1999    -0.9851      0.2029   -0.1788  ...
# 55         0.3433    0.5790     0.8381      0.6909    1.2155  ...
# 56         0.0872   -0.1174    -0.6686      0.1756   -0.0435  ...
# 57         0.1290    0.0060     0.0239      0.2508    0.3589  ...
# 58         0.1243    0.1601     0.6338      0.2526    0.2570  ...
# 59         0.3173    0.3520     0.5533      0.6361    1.1878  ...
# 60         0.2396   -0.1728    -0.3567      0.4845   -0.4887  ...
# 61         0.1696    1.0592     3.1169      0.3398    0.4254  ...
# 62         0.1378   -0.2761    -1.0275      0.2687    0.4492  ...
# 63         0.1495    0.6515     2.1980      0.2964   -0.2570  ...
# 64         0.2960    0.6194     1.0322      0.6001    1.0419  ...
# 65         0.1228   -0.4572    -1.8671      0.2449    0.1714  ...
# 66         0.1977    0.5913     1.5243      0.3879    0.0387  ...
# 67         0.1393   -0.2348    -0.8460      0.2776    0.3738  ...
# 68         0.1393    0.3754     1.3492      0.2783   -0.3561  ...
#
#     Overall_ESG_Exposure_coef  Overall_ESG_Exposure_tstat  \
# 33                     0.6969                      0.3768
# 34                     0.8032                      0.8041
# 35                    -3.4786                     -2.0022
# 36                     0.1734                      0.3362
# 37                     0.0389                      0.3076
# 38                     1.1349                      0.2108
# 39                     3.8293                      0.7974
# 40                     3.1576                      1.3885
# 41                    -0.1048                     -0.1724
# 42                     3.5388                      1.4490
# 43                    -0.3818                     -1.4919
# 44                    -0.6361                     -0.9934
# 45                     1.7755                      1.8739
# 46                    -0.8385                     -0.5201
# 47                    -0.7210                     -0.6975
# 48                    -0.2542                     -0.4161
# 49                     1.2972                      0.2400
# 50                     1.0677                      0.6361
# 51                     0.0105                      0.1557
# 52                     0.5020                      0.3682
# 53                     0.0858                      0.7122
# 54                     0.5022                      1.0181
# 55                     0.8962                      0.8483
# 56                     0.3560                      1.5154
# 57                     0.3695                      0.7930
# 58                     0.3154                      0.7540
# 59                    -1.2376                     -0.6360
# 60                   -18.8105                     -1.5135
# 61                    -0.0317                     -0.2903
# 62                    -0.9227                     -0.6859
# 63                     0.1856                      0.7413
# 64                     0.2971                      0.9558
# 65                     1.0030                      0.8336
# 66                     1.4872                      0.8841
# 67                     0.1618                      0.3085
# 68                     0.1622                      0.3446
#
#     Overall_ESG_Exposure_stderr  Overall_ESG_Sentiment_coef  \
# 33                       1.8496                     -0.0289
# 34                       0.9989                      0.0366
# 35                       1.7374                     -0.0459
# 36                       0.5157                     -0.0220
# 37                       0.1264                      0.0911
# 38                       5.3828                     -0.0851
# 39                       4.8024                     -0.1437
# 40                       2.2741                     -0.0763
# 41                       0.6077                     -0.1366
# 42                       2.4422                     -0.1426
# 43                       0.2559                     -0.4056
# 44                       0.6403                      0.0067
# 45                       0.9475                     -0.2474
# 46                       1.6124                      0.0252
# 47                       1.0337                      0.1853
# 48                       0.6107                     -0.0652
# 49                       5.4051                     -0.0323
# 50                       1.6785                     -0.0431
# 51                       0.0673                     -0.1679
# 52                       1.3634                      0.0475
# 53                       0.1205                     -0.1408
# 54                       0.4933                     -0.0045
# 55                       1.0565                     -0.1482
# 56                       0.2349                     -0.1873
# 57                       0.4660                      0.2620
# 58                       0.4182                     -0.1317
# 59                       1.9459                     -0.4450
# 60                      12.4280                      0.2438
# 61                       0.1093                      0.2054
# 62                       1.3454                      0.1600
# 63                       0.2504                      0.0613
# 64                       0.3109                     -0.3082
# 65                       1.2032                     -0.0666
# 66                       1.6821                     -0.0272
# 67                       0.5244                     -0.2229
# 68                       0.4706                     -0.0968
#
#     Overall_ESG_Sentiment_tstat  Overall_ESG_Sentiment_stderr      R2  Adj_R2  \
# 33                      -0.3905                        0.0741  0.2618  0.1785
# 34                       0.3477                        0.1054  0.5728  0.5246
# 35                      -0.2135                        0.2152  0.3708  0.2998
# 36                      -0.2509                        0.0876  0.7704  0.7445
# 37                       0.8783                        0.1037  0.6767  0.6402
# 38                      -0.7372                        0.1155  0.0551 -0.0515
# 39                      -1.0578                        0.1359  0.6156  0.5722
# 40                      -1.1082                        0.0689  0.4511  0.3892
# 41                      -0.3832                        0.3563  0.4428  0.3799
# 42                      -0.8290                        0.1720  0.3637  0.2919
# 43                      -2.2199                        0.1827  0.6133  0.5697
# 44                       0.0754                        0.0882  0.4040  0.3367
# 45                      -2.8752                        0.0860  0.4200  0.3545
# 46                       0.1730                        0.1455  0.2822  0.2012
# 47                       0.9446                        0.1962  0.5659  0.5169
# 48                      -0.7329                        0.0889  0.2769  0.1953
# 49                      -0.3426                        0.0942  0.5667  0.5178
# 50                      -0.7737                        0.0557  0.4770  0.4179
# 51                      -0.8405                        0.1998  0.5000  0.4435
# 52                       0.5559                        0.0854  0.1990  0.1086
# 53                      -1.4023                        0.1004  0.6132  0.5695
# 54                      -0.0762                        0.0584  0.4999  0.4434
# 55                      -0.4422                        0.3353  0.5741  0.5261
# 56                      -1.6163                        0.1159  0.5094  0.4540
# 57                       0.7681                        0.3411  0.4449  0.3822
# 58                      -0.3348                        0.3934  0.6941  0.6595
# 59                      -1.7943                        0.2480  0.5989  0.5536
# 60                       1.0166                        0.2399  0.0876 -0.0154
# 61                       2.5760                        0.0797  0.6434  0.6032
# 62                       1.0813                        0.1480  0.4028  0.3353
# 63                       0.6230                        0.0984  0.6900  0.6550
# 64                      -1.5326                        0.2011  0.4550  0.3935
# 65                      -0.9033                        0.0737  0.2953  0.2158
# 66                      -0.2061                        0.1321  0.3659  0.2943
# 67                      -0.8433                        0.2643  0.5571  0.5071
# 68                      -1.9964                        0.0485  0.4894  0.4317
#
#     Macro_Sector  Ticker
# 33   Industrials    ABBV
# 34   Industrials     ABT
# 35   Industrials    ANET
# 36   Industrials     APH
# 37   Industrials    APTV
# 38   Industrials    BIIB
# 39   Industrials    BKNG
# 40   Industrials     BSX
# 41   Industrials      CF
# 42   Industrials    CHTR
# 43   Industrials     CMI
# 44   Industrials     DHR
# 45   Industrials      EL
# 46   Industrials    FTNT
# 47   Industrials      GM
# 48   Industrials     HII
# 49   Industrials    ISRG
# 50   Industrials     JNJ
# 51   Industrials      KO
# 52   Industrials      LW
# 53   Industrials    MCHP
# 54   Industrials    MDLZ
# 55   Industrials    NCLH
# 56   Industrials     PEP
# 57   Industrials      PM
# 58   Industrials     PPG
# 59   Industrials     RCL
# 60   Industrials    REGN
# 61   Industrials     SWK
# 62   Industrials       T
# 63   Industrials    TRMB
# 64   Industrials     UAL
# 65   Industrials      VZ
# 66   Industrials    XRAY
# 67   Industrials     XYL
# 68   Industrials     ZTS
#
# [36 rows x 28 columns]
#
# === Ticker‐Level (Consumer): FF5 + ENV ===
#     const_coef  const_tstat  const_stderr  Mkt-RF_coef  Mkt-RF_tstat  \
# 0       0.0151       0.1744        0.0864       0.9586        3.4241
# 1      -0.1122      -1.5324        0.0732       1.3712        7.3774
# 2       0.1250       1.7848        0.0700       0.6580        5.0681
# 3      -0.0392      -0.3675        0.1067       0.7890        4.8158
# 4      -0.0089      -0.2221        0.0400       1.4412        7.3133
# 5       0.1261       2.9347        0.0430       1.0933        8.2567
# 6      -0.0093      -0.4412        0.0211       1.0011        6.4578
# 7      -0.0313      -0.9421        0.0332       0.7547        3.2058
# 8       0.0236       0.6334        0.0373       1.1499        7.6637
# 9      -0.3047      -1.0052        0.3031       1.2507        7.6080
# 10      0.0003       0.0126        0.0270       1.2633        7.3871
# 11      0.0328       0.5177        0.0634       1.3966        6.1644
# 12     -0.0020      -0.0793        0.0255       0.9218        6.0943
# 13      0.0692       1.1250        0.0615       0.8606        5.8468
# 14      0.0111       0.2212        0.0500       1.7551        4.0623
# 15      0.0186       0.7020        0.0265       1.1612        7.2254
# 16      0.0087       0.1623        0.0538       1.0146        5.8447
# 17     -0.0149      -0.4759        0.0314       0.8788        4.7551
# 18      0.0337       1.5208        0.0221       0.5980        5.0589
# 19     -0.0320      -0.1637        0.1954       1.6119        5.8367
#
#     Mkt-RF_stderr  SMB_coef  SMB_tstat  SMB_stderr  HML_coef  ...  \
# 0          0.2800    0.3226     0.6064      0.5320    0.8238  ...
# 1          0.1859   -0.7317    -1.9343      0.3783   -0.1687  ...
# 2          0.1298    0.3912     1.5266      0.2563   -0.0666  ...
# 3          0.1638   -0.3887    -1.1946      0.3254   -0.5020  ...
# 4          0.1971    0.0596     0.1534      0.3886    0.1614  ...
# 5          0.1324   -0.3484    -1.3206      0.2638   -0.4086  ...
# 6          0.1550    0.1294     0.4213      0.3071    0.1032  ...
# 7          0.2354    0.9160     1.9620      0.4669   -0.3501  ...
# 8          0.1500   -0.1213    -0.4046      0.2997    0.6728  ...
# 9          0.1644    0.4656     1.4076      0.3308    0.0286  ...
# 10         0.1710   -0.1809    -0.5373      0.3368    0.4403  ...
# 11         0.2266    1.1824     2.6053      0.4538   -0.2681  ...
# 12         0.1513    0.2844     0.9439      0.3013    0.4173  ...
# 13         0.1472   -0.1284    -0.4462      0.2876    0.0204  ...
# 14         0.4320    1.6662     1.9899      0.8373   -0.2311  ...
# 15         0.1607    0.2732     0.8670      0.3151    0.4846  ...
# 16         0.1736    0.0759     0.2179      0.3486    0.0933  ...
# 17         0.1848   -0.2560    -0.7039      0.3637   -0.4715  ...
# 18         0.1182   -0.1962    -0.8581      0.2286   -0.3575  ...
# 19         0.2762    0.5097     0.9117      0.5590    0.7596  ...
#
#     Overall_ESG_Exposure_coef  Overall_ESG_Exposure_tstat  \
# 0                     -0.1655                     -0.1673
# 1                      4.7442                      1.5834
# 2                     -2.7339                     -0.7826
# 3                      2.6106                      0.4426
# 4                      0.3269                      0.3994
# 5                     -4.0214                     -2.5083
# 6                      0.2655                      0.2608
# 7                      0.5316                      0.9812
# 8                     -0.4596                     -0.4977
# 9                      8.3689                      0.8457
# 10                    -2.7534                     -2.2255
# 11                    -0.8382                     -0.6600
# 12                     0.4194                      0.5395
# 13                    -1.3314                     -0.9294
# 14                     1.4558                      1.0500
# 15                    -1.8565                     -1.0576
# 16                     0.2591                      0.1188
# 17                    -0.6386                     -0.3170
# 18                     0.3212                      0.2443
# 19                     0.5733                      0.0978
#
#     Overall_ESG_Exposure_stderr  Overall_ESG_Sentiment_coef  \
# 0                        0.9889                     -0.1297
# 1                        2.9962                      0.1101
# 2                        3.4933                     -0.2646
# 3                        5.8983                     -0.0243
# 4                        0.8183                     -0.0686
# 5                        1.6032                     -0.2575
# 6                        1.0179                     -0.0116
# 7                        0.5418                     -0.0374
# 8                        0.9236                      0.0337
# 9                        9.8954                      0.5028
# 10                       1.2372                      0.3297
# 11                       1.2699                     -0.0322
# 12                       0.7775                     -0.0562
# 13                       1.4326                     -0.0395
# 14                       1.3865                     -0.1321
# 15                       1.7554                     -0.0120
# 16                       2.1805                     -0.0360
# 17                       2.0147                      0.0982
# 18                       1.3144                     -0.1297
# 19                       5.8637                      0.0027
#
#     Overall_ESG_Sentiment_tstat  Overall_ESG_Sentiment_stderr      R2  Adj_R2  \
# 0                       -1.5682                        0.0827  0.3083  0.2429
# 1                        0.7053                        0.1561  0.5385  0.4864
# 2                       -1.4110                        0.1875  0.4423  0.3793
# 3                       -0.1403                        0.1730  0.3411  0.2668
# 4                       -0.8010                        0.0856  0.5444  0.4930
# 5                       -1.6449                        0.1566  0.6619  0.6237
# 6                       -0.1751                        0.0665  0.4917  0.4343
# 7                       -0.2429                        0.1538  0.2992  0.2201
# 8                        0.4431                        0.0760  0.6025  0.5577
# 9                        1.0648                        0.4722  0.6232  0.5807
# 10                       2.1417                        0.1540  0.5719  0.5235
# 11                      -0.3250                        0.0991  0.5530  0.5025
# 12                      -0.4240                        0.1325  0.5320  0.4792
# 13                      -0.4230                        0.0934  0.4420  0.3790
# 14                      -1.1023                        0.1198  0.4012  0.3336
# 15                      -0.2718                        0.0441  0.5993  0.5540
# 16                      -0.6131                        0.0587  0.4358  0.3721
# 17                       1.1366                        0.0864  0.3502  0.2768
# 18                      -0.8533                        0.1520  0.3698  0.2986
# 19                       0.0195                        0.1387  0.5142  0.4594
#
#     Macro_Sector  Ticker
# 0       Consumer     AAP
# 1       Consumer    ADBE
# 2       Consumer     ADP
# 3       Consumer    AKAM
# 4       Consumer     BBY
# 5       Consumer    CDNS
# 6       Consumer    CTSH
# 7       Consumer    DLTR
# 8       Consumer     HLT
# 9       Consumer     IQV
# 10      Consumer      IT
# 11      Consumer     KMX
# 12      Consumer     OMC
# 13      Consumer    ORLY
# 14      Consumer    PENN
# 15      Consumer     RHI
# 16      Consumer    ROST
# 17      Consumer    TTWO
# 18      Consumer     WMT
# 19      Consumer    WYNN
#
# [20 rows x 28 columns]
#
# === Ticker‐Level (Energy & Utilities): FF5 + ENV ===
#     const_coef  const_tstat  const_stderr  Mkt-RF_coef  Mkt-RF_tstat  \
# 20      0.0150       0.2928        0.0513       0.5905        4.2181
# 21     -0.0475      -0.9226        0.0515       1.0694        4.4330
# 22      0.0143       0.8464        0.0169       1.4523        7.7504
# 23     -0.0055      -0.1365        0.0401       0.5715        3.8189
# 24     -0.0016      -0.0352        0.0464       0.5438        4.1842
# 25      0.0130       0.2339        0.0555       0.4359        2.8596
# 26      0.0031       0.1070        0.0286       0.5331        4.5137
# 27      0.0087       0.3503        0.0247       0.5851        4.3971
# 28     -0.1168      -1.5242        0.0766       0.5131        3.2404
# 29     -0.0307      -0.9346        0.0328       0.8116        7.0164
# 30     -0.0361      -0.4220        0.0855       1.5644        7.3157
# 31     -0.0143      -0.3672        0.0390       0.4711        3.5728
# 32     -0.3998      -1.6659        0.2400       1.1185        6.9717
#
#     Mkt-RF_stderr  SMB_coef  SMB_tstat  SMB_stderr  HML_coef  ...  \
# 20         0.1400   -0.2982    -1.0729      0.2779    0.1033  ...
# 21         0.2412    0.2075     0.4284      0.4843    0.0436  ...
# 22         0.1874    0.1165     0.3063      0.3804   -0.4853  ...
# 23         0.1497   -0.1349    -0.4515      0.2988    0.1638  ...
# 24         0.1300   -0.1665    -0.6537      0.2546    0.1601  ...
# 25         0.1524    0.1288     0.4204      0.3063    0.0979  ...
# 26         0.1181   -0.3662    -1.5702      0.2332    0.2969  ...
# 27         0.1331   -0.1311    -0.5019      0.2613    0.0470  ...
# 28         0.1583   -0.0615    -0.1903      0.3234    0.1668  ...
# 29         0.1157   -0.0580    -0.2520      0.2303    0.1600  ...
# 30         0.2138    0.1039     0.2445      0.4249    1.6731  ...
# 31         0.1319   -0.3492    -1.3407      0.2604   -0.0327  ...
# 32         0.1604   -0.3420    -1.0959      0.3121    0.7354  ...
#
#     Overall_ESG_Exposure_coef  Overall_ESG_Exposure_tstat  \
# 20                    -0.3989                     -0.8799
# 21                     0.2747                      1.2028
# 22                    12.5560                      0.6564
# 23                     0.0635                      0.6479
# 24                     0.0370                      0.2141
# 25                    -0.5009                     -1.2790
# 26                    -0.0992                     -0.9657
# 27                    -0.0414                     -0.5366
# 28                     0.1157                      0.8187
# 29                     0.2589                      1.2337
# 30                     0.0000                      0.0001
# 31                     0.0227                      0.4014
# 32                     0.9861                      1.5617
#
#     Overall_ESG_Exposure_stderr  Overall_ESG_Sentiment_coef  \
# 20                       0.4534                      0.3290
# 21                       0.2284                     -0.4668
# 22                      19.1272                     -0.3882
# 23                       0.0980                     -0.0643
# 24                       0.1730                     -0.0562
# 25                       0.3916                      0.3245
# 26                       0.1028                      0.0884
# 27                       0.0772                      0.0293
# 28                       0.1413                      0.4066
# 29                       0.2098                     -0.1623
# 30                       0.3043                      0.1476
# 31                       0.0565                     -0.0154
# 32                       0.6314                      0.3728
#
#     Overall_ESG_Sentiment_tstat  Overall_ESG_Sentiment_stderr      R2  Adj_R2  \
# 20                       1.0142                        0.3244  0.2797  0.1983
# 21                      -1.6340                        0.2857  0.3383  0.2636
# 22                      -0.7681                        0.5054  0.5691  0.5204
# 23                      -0.3936                        0.1635  0.2547  0.1706
# 24                      -0.4342                        0.1295  0.3570  0.2845
# 25                       1.9358                        0.1676  0.2414  0.1558
# 26                       1.3490                        0.0655  0.3824  0.3127
# 27                       0.4847                        0.0604  0.3223  0.2458
# 28                       1.5911                        0.2556  0.2664  0.1836
# 29                      -1.1022                        0.1473  0.5454  0.4941
# 30                       0.6132                        0.2407  0.7052  0.6719
# 31                      -0.1193                        0.1295  0.2748  0.1930
# 32                       1.8077                        0.2063  0.5631  0.5138
#
#           Macro_Sector  Ticker
# 20  Energy & Utilities     AEP
# 21  Energy & Utilities     AES
# 22  Energy & Utilities     EFX
# 23  Energy & Utilities    EVRG
# 24  Energy & Utilities     EXC
# 25  Energy & Utilities      FE
# 26  Energy & Utilities      NI
# 27  Energy & Utilities     PEG
# 28  Energy & Utilities     PNW
# 29  Energy & Utilities     PPL
# 30  Energy & Utilities     SLB
# 31  Energy & Utilities     WEC
# 32  Energy & Utilities     WMB
#
# [13 rows x 28 columns]
#
# Done! All tables printed.

# %%
import pandas as pd
import statsmodels.api as sm

# === Load data ===
df = pd.read_excel(
    'climate_final_with_ff5_and_excess_return.xlsx',
    sheet_name='climate_final_with_ff5_and_exce',
    parse_dates=['date']
)

# === Define factor sets ===
fama_french_factors = ['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA']
env_factors = ['Overall_ESG_Exposure', 'Overall_ESG_Sentiment']

# === Filter to only the tickers shown in the LaTeX tables ===
selected_tickers = [
    # Panel A: Industrials
    'ZTS', 'PEP', 'ANET', 'JNJ', 'CMI', 'SWK', 'BSX', 'RCL', 'EL',
    # Panel B: Consumer
    'CDNS', 'ORLY', 'IT', 'AAP',
    # Panel C: Energy & Utilities
    'WMB', 'AES'
]
df = df[df['TICKER'].isin(selected_tickers)]

# === Helper function to run regressions and extract stats ===
def run_regression(y, X):
    X = sm.add_constant(X)
    model = sm.OLS(y, X).fit()
    results = {}
    for var in X.columns:
        results[f'{var}_coef']   = model.params[var]
        results[f'{var}_tstat']  = model.tvalues[var]
        results[f'{var}_stderr'] = model.bse[var]
    results['R2']     = model.rsquared
    results['Adj_R2'] = model.rsquared_adj
    return results

# === 1. Macro‐Sector Level Regressions ===
sector_results_fama     = []
sector_results_fama_env = []

for sector, group in df.groupby('Macro_Sector'):
    # FF5 only
    res_fama = run_regression(group['excess_RET'], group[fama_french_factors])
    res_fama['Macro_Sector'] = sector
    sector_results_fama.append(res_fama)
    # FF5 + ENV
    res_fama_env = run_regression(group['excess_RET'], group[fama_french_factors + env_factors])
    res_fama_env['Macro_Sector'] = sector
    sector_results_fama_env.append(res_fama_env)

sector_df_fama     = pd.DataFrame(sector_results_fama)
sector_df_fama_env = pd.DataFrame(sector_results_fama_env)

# === 2. Ticker‐Level Regressions (Filtered Tickers Only) ===
ticker_results_fama     = []
ticker_results_fama_env = []

for (sector, ticker), group in df.groupby(['Macro_Sector', 'TICKER']):
    # FF5 only
    res_t_fama = run_regression(group['excess_RET'], group[fama_french_factors])
    res_t_fama['Macro_Sector'] = sector
    res_t_fama['Ticker']       = ticker
    ticker_results_fama.append(res_t_fama)
    # FF5 + ENV
    res_t_fama_env = run_regression(group['excess_RET'], group[fama_french_factors + env_factors])
    res_t_fama_env['Macro_Sector'] = sector
    res_t_fama_env['Ticker']       = ticker
    ticker_results_fama_env.append(res_t_fama_env)

ticker_df_fama     = pd.DataFrame(ticker_results_fama)
ticker_df_fama_env = pd.DataFrame(ticker_results_fama_env)

# === 3. Print Results ===
print("\n=== Macro‐Sector Level: FF5 Only ===")
print(sector_df_fama.round(4))

print("\n=== Macro‐Sector Level: FF5 + ENV ===")
print(sector_df_fama_env.round(4))

for name, df_t in [
    ("Industrials", ticker_df_fama[ticker_df_fama['Macro_Sector']=='Industrials']),
    ("Consumer",    ticker_df_fama[ticker_df_fama['Macro_Sector']=='Consumer']),
    ("Energy & Utilities", ticker_df_fama[ticker_df_fama['Macro_Sector']=='Energy & Utilities'])
]:
    print(f"\n=== Ticker‐Level ({name}): FF5 Only ===")
    print(df_t.round(4))

for name, df_t in [
    ("Industrials", ticker_df_fama_env[ticker_df_fama_env['Macro_Sector']=='Industrials']),
    ("Consumer",    ticker_df_fama_env[ticker_df_fama_env['Macro_Sector']=='Consumer']),
    ("Energy & Utilities", ticker_df_fama_env[ticker_df_fama_env['Macro_Sector']=='Energy & Utilities'])
]:
    print(f"\n=== Ticker‐Level ({name}): FF5 + ENV ===")
    print(df_t.round(4))

print("\nDone! All tables printed.")
# Out:
# === Macro‐Sector Level: FF5 Only ===
#    const_coef  const_tstat  const_stderr  Mkt-RF_coef  Mkt-RF_tstat  \
# 0     -0.0003      -0.0586        0.0051       1.0003        9.4360
# 1     -0.0013      -0.1925        0.0070       1.0616        7.3924
# 2     -0.0027      -0.7935        0.0034       0.9948       14.1435
#
#    Mkt-RF_stderr  SMB_coef  SMB_tstat  SMB_stderr  HML_coef  ...  HML_stderr  \
# 0         0.1060    0.0902     0.4391      0.2055    0.1744  ...      0.1768
# 1         0.1436    0.0304     0.1073      0.2835    0.3028  ...      0.2381
# 2         0.0703    0.1688     1.2159      0.1389    0.0401  ...      0.1166
#
#    RMW_coef  RMW_tstat  RMW_stderr  CMA_coef  CMA_tstat  CMA_stderr      R2  \
# 0    0.2779     1.1655      0.2384   -0.1855    -0.7387      0.2511  0.3118
# 1   -0.1168    -0.3604      0.3242    0.6640     1.9635      0.3382  0.3798
# 2    0.3859     2.4301      0.1588    0.1365     0.8241      0.1656  0.3134
#
#    Adj_R2        Macro_Sector
# 0  0.2998            Consumer
# 1  0.3566  Energy & Utilities
# 2  0.3079         Industrials
#
# [3 rows x 21 columns]
#
# === Macro‐Sector Level: FF5 + ENV ===
#    const_coef  const_tstat  const_stderr  Mkt-RF_coef  Mkt-RF_tstat  \
# 0      0.0323       2.9277        0.0110       1.0058        9.6476
# 1     -0.0041      -0.1121        0.0367       1.0660        7.3391
# 2      0.0016       0.2430        0.0066       0.9944       14.1249
#
#    Mkt-RF_stderr  SMB_coef  SMB_tstat  SMB_stderr  HML_coef  ...  CMA_stderr  \
# 0         0.1043    0.0408     0.2010      0.2029    0.2050  ...      0.2488
# 1         0.1453    0.0333     0.1162      0.2865    0.2902  ...      0.3406
# 2         0.0704    0.1599     1.1508      0.1390    0.0491  ...      0.1658
#
#    Overall_ESG_Exposure_coef  Overall_ESG_Exposure_tstat  \
# 0                    -0.4695                     -2.7953
# 1                    -0.0205                     -0.1604
# 2                     0.0338                      0.6574
#
#    Overall_ESG_Exposure_stderr  Overall_ESG_Sentiment_coef  \
# 0                       0.1680                     -0.0727
# 1                       0.1280                      0.0455
# 2                       0.0514                     -0.0265
#
#    Overall_ESG_Sentiment_tstat  Overall_ESG_Sentiment_stderr      R2  Adj_R2  \
# 0                      -1.7468                        0.0416  0.3394  0.3231
# 1                       0.8319                        0.0548  0.3830  0.3503
# 2                      -1.3668                        0.0194  0.3160  0.3083
#
#          Macro_Sector
# 0            Consumer
# 1  Energy & Utilities
# 2         Industrials
#
# [3 rows x 27 columns]
#
# === Ticker‐Level (Industrials): FF5 Only ===
#     const_coef  const_tstat  const_stderr  Mkt-RF_coef  Mkt-RF_tstat  \
# 6       0.0131       1.0710        0.0123       1.2030        4.7532
# 7       0.0014       0.2168        0.0063       0.8299        6.4302
# 8       0.0053       0.8107        0.0065       1.0056        7.4448
# 9      -0.0212      -1.9913        0.0107       0.8442        3.8334
# 10     -0.0066      -1.4080        0.0047       0.5872        6.0449
# 11     -0.0043      -1.0063        0.0042       0.5185        5.9225
# 12      0.0069       0.4458        0.0154       2.2482        7.0788
# 13     -0.0162      -1.8261        0.0089       1.0015        5.4635
# 14     -0.0026      -0.3857        0.0068       0.7154        5.0766
#
#     Mkt-RF_stderr  SMB_coef  SMB_tstat  SMB_stderr  HML_coef  ...  RMW_coef  \
# 6          0.2531   -0.5050    -1.0106      0.4997   -0.5532  ...    0.4042
# 7          0.1291   -0.5624    -2.2073      0.2548    0.1718  ...   -0.0665
# 8          0.1351    0.1058     0.3968      0.2667    0.4517  ...   -0.1546
# 9          0.2202    0.8874     2.0411      0.4347   -0.5632  ...    1.2253
# 10         0.0971    0.1144     0.5966      0.1918   -0.2948  ...    0.3659
# 11         0.0875   -0.0547    -0.3166      0.1728   -0.1194  ...    0.5724
# 12         0.3176    0.1133     0.1807      0.6270    1.3991  ...   -0.7054
# 13         0.1833    0.9484     2.6208      0.3619    0.3486  ...    1.0607
# 14         0.1409    0.4723     1.6976      0.2782   -0.4795  ...    0.7708
#
#     RMW_tstat  RMW_stderr  CMA_coef  CMA_tstat  CMA_stderr      R2  Adj_R2  \
# 6      0.7075      0.5714    0.3331     0.5588      0.5960  0.3168  0.2634
# 7     -0.2281      0.2913    0.0896     0.2948      0.3039  0.4160  0.3703
# 8     -0.5069      0.3049    0.0989     0.3110      0.3181  0.5823  0.5497
# 9      2.4647      0.4971    0.3666     0.7069      0.5186  0.3409  0.2894
# 10     1.6685      0.2193    0.9281     4.0569      0.2288  0.4719  0.4306
# 11     2.8959      0.1976    0.5244     2.5436      0.2062  0.4826  0.4422
# 12    -0.9839      0.7170   -0.9204    -1.2307      0.7479  0.5766  0.5435
# 13     2.5634      0.4138   -0.1345    -0.3117      0.4316  0.5613  0.5270
# 14     2.4227      0.3182   -0.0573    -0.1726      0.3319  0.4564  0.4140
#
#     Macro_Sector  Ticker
# 6    Industrials    ANET
# 7    Industrials     BSX
# 8    Industrials     CMI
# 9    Industrials      EL
# 10   Industrials     JNJ
# 11   Industrials     PEP
# 12   Industrials     RCL
# 13   Industrials     SWK
# 14   Industrials     ZTS
#
# [9 rows x 22 columns]
#
# === Ticker‐Level (Consumer): FF5 Only ===
#    const_coef  const_tstat  const_stderr  Mkt-RF_coef  Mkt-RF_tstat  \
# 0     -0.0220      -1.6720        0.0131       0.9624        3.4305
# 1      0.0129       1.9561        0.0066       1.0531        7.7156
# 2      0.0086       1.0003        0.0086       1.1961        6.7704
# 3      0.0041       0.5827        0.0070       0.8438        5.8465
#
#    Mkt-RF_stderr  SMB_coef  SMB_tstat  SMB_stderr  HML_coef  ...  RMW_coef  \
# 0         0.2805    0.5160     0.9938      0.5192    0.6401  ...    0.6152
# 1         0.1365   -0.2162    -0.8022      0.2695   -0.4699  ...   -0.0039
# 2         0.1767   -0.0831    -0.2382      0.3488    0.5073  ...   -0.2363
# 3         0.1443   -0.1103    -0.3870      0.2849    0.0560  ...    0.5797
#
#    RMW_tstat  RMW_stderr  CMA_coef  CMA_tstat  CMA_stderr      R2  Adj_R2  \
# 0     0.9844      0.6249    0.1071     0.1587      0.6752  0.2850  0.2379
# 1    -0.0127      0.3081   -0.5257    -1.6356      0.3214  0.6227  0.5932
# 2    -0.5925      0.3988   -0.5253    -1.2626      0.4160  0.5162  0.4784
# 3     1.7793      0.3258    0.1302     0.3832      0.3399  0.4317  0.3873
#
#    Macro_Sector  Ticker
# 0      Consumer     AAP
# 1      Consumer    CDNS
# 2      Consumer      IT
# 3      Consumer    ORLY
#
# [4 rows x 22 columns]
#
# === Ticker‐Level (Energy & Utilities): FF5 Only ===
#    const_coef  const_tstat  const_stderr  Mkt-RF_coef  Mkt-RF_tstat  \
# 4     -0.0078      -0.6717        0.0116       1.0513        4.3747
# 5      0.0051       0.6685        0.0077       1.0719        6.7522
#
#    Mkt-RF_stderr  SMB_coef  SMB_tstat  SMB_stderr  HML_coef  ...  RMW_coef  \
# 4         0.2403    0.3465     0.7303      0.4744   -0.0963  ...   -0.1918
# 5         0.1587   -0.2856    -0.9113      0.3134    0.7018  ...   -0.0418
#
#    RMW_tstat  RMW_stderr  CMA_coef  CMA_tstat  CMA_stderr      R2  Adj_R2  \
# 4    -0.3536      0.5425    1.0256     1.8123      0.5659  0.3098  0.2558
# 5    -0.1168      0.3584    0.3024     0.8089      0.3738  0.5398  0.5038
#
#          Macro_Sector  Ticker
# 4  Energy & Utilities     AES
# 5  Energy & Utilities     WMB
#
# [2 rows x 22 columns]
#
# === Ticker‐Level (Industrials): FF5 + ENV ===
#     const_coef  const_tstat  const_stderr  Mkt-RF_coef  Mkt-RF_tstat  \
# 6       0.0699       1.5902        0.0440       1.2619        5.0386
# 7      -0.0715      -0.9343        0.0766       0.8521        6.6248
# 8       0.0642       1.7487        0.0367       1.0060        7.4629
# 9      -0.0062      -0.4119        0.0151       0.8505        4.0490
# 10     -0.0093      -0.6696        0.0138       0.5867        5.8909
# 11      0.0029       0.1186        0.0241       0.5275        6.0467
# 12      0.2223       1.2556        0.1770       2.2396        7.0578
# 13     -0.0499      -3.9146        0.0127       0.9117        5.3756
# 14      0.0317       0.8818        0.0359       0.6923        4.9704
#
#     Mkt-RF_stderr  SMB_coef  SMB_tstat  SMB_stderr  HML_coef  ...  \
# 6          0.2504   -0.4179    -0.8495      0.4919   -0.8003  ...
# 7          0.1286   -0.4569    -1.7792      0.2568    0.0165  ...
# 8          0.1348    0.1536     0.5874      0.2616    0.4579  ...
# 9          0.2100    0.7601     1.7931      0.4239   -0.4055  ...
# 10         0.0996    0.0837     0.4213      0.1986   -0.2583  ...
# 11         0.0872   -0.1174    -0.6686      0.1756   -0.0435  ...
# 12         0.3173    0.3520     0.5533      0.6361    1.1878  ...
# 13         0.1696    1.0592     3.1169      0.3398    0.4254  ...
# 14         0.1393    0.3754     1.3492      0.2783   -0.3561  ...
#
#     Overall_ESG_Exposure_coef  Overall_ESG_Exposure_tstat  \
# 6                     -3.4786                     -2.0022
# 7                      3.1576                      1.3885
# 8                     -0.3818                     -1.4919
# 9                      1.7755                      1.8739
# 10                     1.0677                      0.6361
# 11                     0.3560                      1.5154
# 12                    -1.2376                     -0.6360
# 13                    -0.0317                     -0.2903
# 14                     0.1622                      0.3446
#
#     Overall_ESG_Exposure_stderr  Overall_ESG_Sentiment_coef  \
# 6                        1.7374                     -0.0459
# 7                        2.2741                     -0.0763
# 8                        0.2559                     -0.4056
# 9                        0.9475                     -0.2474
# 10                       1.6785                     -0.0431
# 11                       0.2349                     -0.1873
# 12                       1.9459                     -0.4450
# 13                       0.1093                      0.2054
# 14                       0.4706                     -0.0968
#
#     Overall_ESG_Sentiment_tstat  Overall_ESG_Sentiment_stderr      R2  Adj_R2  \
# 6                       -0.2135                        0.2152  0.3708  0.2998
# 7                       -1.1082                        0.0689  0.4511  0.3892
# 8                       -2.2199                        0.1827  0.6133  0.5697
# 9                       -2.8752                        0.0860  0.4200  0.3545
# 10                      -0.7737                        0.0557  0.4770  0.4179
# 11                      -1.6163                        0.1159  0.5094  0.4540
# 12                      -1.7943                        0.2480  0.5989  0.5536
# 13                       2.5760                        0.0797  0.6434  0.6032
# 14                      -1.9964                        0.0485  0.4894  0.4317
#
#     Macro_Sector  Ticker
# 6    Industrials    ANET
# 7    Industrials     BSX
# 8    Industrials     CMI
# 9    Industrials      EL
# 10   Industrials     JNJ
# 11   Industrials     PEP
# 12   Industrials     RCL
# 13   Industrials     SWK
# 14   Industrials     ZTS
#
# [9 rows x 28 columns]
#
# === Ticker‐Level (Consumer): FF5 + ENV ===
#    const_coef  const_tstat  const_stderr  Mkt-RF_coef  Mkt-RF_tstat  \
# 0      0.0151       0.1744        0.0864       0.9586        3.4241
# 1      0.1261       2.9347        0.0430       1.0933        8.2567
# 2      0.0003       0.0126        0.0270       1.2633        7.3871
# 3      0.0692       1.1250        0.0615       0.8606        5.8468
#
#    Mkt-RF_stderr  SMB_coef  SMB_tstat  SMB_stderr  HML_coef  ...  \
# 0         0.2800    0.3226     0.6064      0.5320    0.8238  ...
# 1         0.1324   -0.3484    -1.3206      0.2638   -0.4086  ...
# 2         0.1710   -0.1809    -0.5373      0.3368    0.4403  ...
# 3         0.1472   -0.1284    -0.4462      0.2876    0.0204  ...
#
#    Overall_ESG_Exposure_coef  Overall_ESG_Exposure_tstat  \
# 0                    -0.1655                     -0.1673
# 1                    -4.0214                     -2.5083
# 2                    -2.7534                     -2.2255
# 3                    -1.3314                     -0.9294
#
#    Overall_ESG_Exposure_stderr  Overall_ESG_Sentiment_coef  \
# 0                       0.9889                     -0.1297
# 1                       1.6032                     -0.2575
# 2                       1.2372                      0.3297
# 3                       1.4326                     -0.0395
#
#    Overall_ESG_Sentiment_tstat  Overall_ESG_Sentiment_stderr      R2  Adj_R2  \
# 0                      -1.5682                        0.0827  0.3083  0.2429
# 1                      -1.6449                        0.1566  0.6619  0.6237
# 2                       2.1417                        0.1540  0.5719  0.5235
# 3                      -0.4230                        0.0934  0.4420  0.3790
#
#    Macro_Sector  Ticker
# 0      Consumer     AAP
# 1      Consumer    CDNS
# 2      Consumer      IT
# 3      Consumer    ORLY
#
# [4 rows x 28 columns]
#
# === Ticker‐Level (Energy & Utilities): FF5 + ENV ===
#    const_coef  const_tstat  const_stderr  Mkt-RF_coef  Mkt-RF_tstat  \
# 4     -0.0475      -0.9226        0.0515       1.0694        4.4330
# 5     -0.3998      -1.6659        0.2400       1.1185        6.9717
#
#    Mkt-RF_stderr  SMB_coef  SMB_tstat  SMB_stderr  HML_coef  ...  \
# 4         0.2412    0.2075     0.4284      0.4843    0.0436  ...
# 5         0.1604   -0.3420    -1.0959      0.3121    0.7354  ...
#
#    Overall_ESG_Exposure_coef  Overall_ESG_Exposure_tstat  \
# 4                     0.2747                      1.2028
# 5                     0.9861                      1.5617
#
#    Overall_ESG_Exposure_stderr  Overall_ESG_Sentiment_coef  \
# 4                       0.2284                     -0.4668
# 5                       0.6314                      0.3728
#
#    Overall_ESG_Sentiment_tstat  Overall_ESG_Sentiment_stderr      R2  Adj_R2  \
# 4                      -1.6340                        0.2857  0.3383  0.2636
# 5                       1.8077                        0.2063  0.5631  0.5138
#
#          Macro_Sector  Ticker
# 4  Energy & Utilities     AES
# 5  Energy & Utilities     WMB
#
# [2 rows x 28 columns]
#
# Done! All tables printed.
