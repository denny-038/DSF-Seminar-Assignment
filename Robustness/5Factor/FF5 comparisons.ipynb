# %%
import pandas as pd
import statsmodels.api as sm

# Load your data from Excel
df = pd.read_excel('climate_final_with_ff5_and_excess_return.xlsx', sheet_name='climate_final_with_ff5_and_exce', parse_dates=['date'])

# Define your factor lists
fama_french_factors = ['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA']
env_factors = ['Overall_ESG_Exposure', 'Overall_ESG_Sentiment']

# Helper function to run regressions and collect results
def run_regression(y, X):
    X = sm.add_constant(X)
    model = sm.OLS(y, X).fit()
    results = {}
    for var in X.columns:
        results[f'{var}_coef'] = model.params[var]
        results[f'{var}_tstat'] = model.tvalues[var]
    results['R2'] = model.rsquared
    results['Adj_R2'] = model.rsquared_adj
    results['n_obs']   = int(model.nobs)
    return results

# --- 1. Macro Sector Level Regression ---
sector_results_fama = []
sector_results_fama_env = []

for sector, group in df.groupby('Macro_Sector'):
    # Fama-French only
    res_fama = run_regression(group['excess_RET'], group[fama_french_factors])
    res_fama['Macro_Sector'] = sector
    sector_results_fama.append(res_fama)
    
    # Fama-French + ENV
    res_fama_env = run_regression(group['excess_RET'], group[fama_french_factors + env_factors])
    res_fama_env['Macro_Sector'] = sector
    sector_results_fama_env.append(res_fama_env)

sector_df_fama = pd.DataFrame(sector_results_fama)
sector_df_fama_env = pd.DataFrame(sector_results_fama_env)

# --- 2. Ticker Level Regression (within each Macro Sector) ---
ticker_results = []

ticker_groups = df.groupby(['Macro_Sector', 'TICKER'])

for (sector, ticker), group in ticker_groups:
    res = run_regression(group['excess_RET'], group[fama_french_factors + env_factors])
    res['Macro_Sector'] = sector
    res['Ticker'] = ticker
    ticker_results.append(res)

full_ticker_df = pd.DataFrame(ticker_results)

# --- 3. Pretty-printing ---
# Split ticker results by sector
industrials = full_ticker_df[full_ticker_df['Macro_Sector'] == 'Industrials']
consumer = full_ticker_df[full_ticker_df['Macro_Sector'] == 'Consumer']
energy_utilities = full_ticker_df[full_ticker_df['Macro_Sector'] == 'Energy & Utilities']

# Print results
print("\n=== Macro-Sector Level Regression: Fama-French Only ===")
print(sector_df_fama.round(4))

print("\n=== Macro-Sector Level Regression: Fama-French + ENV Factors ===")
print(sector_df_fama_env.round(4))

print("\n=== Ticker-Level Regression: Industrials ===")
print(industrials.round(4))

print("\n=== Ticker-Level Regression: Consumer ===")
print(consumer.round(4))

print("\n=== Ticker-Level Regression: Energy & Utilities ===")
print(energy_utilities.round(4))

print("\nDone! All tables printed.")
# Out:
# === Macro-Sector Level Regression: Fama-French Only ===
#    const_coef  const_tstat  Mkt-RF_coef  Mkt-RF_tstat  SMB_coef  SMB_tstat  \
# 0     -0.0034      -1.4755       1.0880       22.7770    0.2473     2.6322
# 1     -0.0033      -1.3986       0.7781       16.1851   -0.1016    -1.0700
# 2     -0.0028      -1.6424       0.9543       27.3059    0.1912     2.7711
#
#    HML_coef  HML_tstat  RMW_coef  RMW_tstat  CMA_coef  CMA_tstat      R2  \
# 0    0.0279     0.3514    0.2349     2.1803   -0.0072    -0.0639  0.3478
# 1    0.2424     3.0405    0.1790     1.6497    0.3939     3.4795  0.2976
# 2    0.1192     2.0578    0.2319     2.9392    0.1330     1.6157  0.3019
#
#    Adj_R2  n_obs        Macro_Sector
# 0  0.3455   1412            Consumer
# 1  0.2937    910  Energy & Utilities
# 2  0.3005   2520         Industrials
#
# === Macro-Sector Level Regression: Fama-French + ENV Factors ===
#    const_coef  const_tstat  Mkt-RF_coef  Mkt-RF_tstat  SMB_coef  SMB_tstat  \
# 0      0.0032       0.5697       1.0891       22.7940    0.2452     2.6090
# 1     -0.0043      -0.6139       0.7790       16.1943   -0.0974    -1.0245
# 2      0.0010       0.2788       0.9554       27.3364    0.1875     2.7178
#
#    HML_coef  HML_tstat  RMW_coef  RMW_tstat  CMA_coef  CMA_tstat  \
# 0    0.0284     0.3581    0.2330     2.1615   -0.0107    -0.0946
# 1    0.2354     2.9407    0.1791     1.6488    0.4011     3.5349
# 2    0.1218     2.1013    0.2290     2.9023    0.1245     1.5114
#
#    Overall_ESG_Exposure_coef  Overall_ESG_Exposure_tstat  \
# 0                    -0.1212                     -1.1132
# 1                    -0.0096                     -0.6000
# 2                     0.0117                      0.6152
#
#    Overall_ESG_Sentiment_coef  Overall_ESG_Sentiment_tstat      R2  Adj_R2  \
# 0                     -0.0124                      -0.8517  0.3487  0.3454
# 1                      0.0173                       0.8047  0.2985  0.2931
# 2                     -0.0174                      -1.7067  0.3029  0.3009
#
#    n_obs        Macro_Sector
# 0   1412            Consumer
# 1    910  Energy & Utilities
# 2   2520         Industrials
#
# === Ticker-Level Regression: Industrials ===
#     const_coef  const_tstat  Mkt-RF_coef  Mkt-RF_tstat  SMB_coef  SMB_tstat  \
# 33      0.0102       0.2833       0.5299        3.1539    0.3037     0.9131
# 34     -0.0447      -1.0647       0.8285        7.7314    0.0037     0.0176
# 35      0.0699       1.5902       1.2619        5.0386   -0.4179    -0.8495
# 36      0.0024       0.0452       1.1519       11.6496    0.0958     0.4801
# 37     -0.0398      -1.2924       1.4432        7.0912    1.3633     3.4400
# 38     -0.0108      -0.3095      -0.0078       -0.0296    0.5252     0.9721
# 39      0.0071       0.1181       1.3672        8.3619   -0.2666    -0.8327
# 40     -0.0715      -0.9343       0.8521        6.6248   -0.4569    -1.7792
# 41      0.0792       0.3420       0.9828        4.4287    0.5453     1.2381
# 42     -0.0084      -0.1112       0.8133        3.6449    0.6086     1.3796
# 43      0.0642       1.7487       1.0060        7.4629    0.1536     0.5874
# 44      0.0133       1.1026       0.7901        5.3315   -0.0121    -0.0413
# 45     -0.0062      -0.4119       0.8505        4.0490    0.7601     1.7931
# 46      0.0237       0.9011       1.0457        3.8948    0.0884     0.1677
# 47      0.0293       0.2008       1.2856        6.3367    0.5641     1.4009
# 48      0.0412       0.6700       0.5267        2.6333    0.0954     0.2394
# 49     -0.0092      -0.1192       1.5137        8.4913   -0.4930    -1.3989
# 50     -0.0093      -0.6696       0.5867        5.8909    0.0837     0.4213
# 51      0.0283       0.5179       0.5749        5.7477   -0.3319    -1.6564
# 52     -0.0518      -0.5743       0.7444        3.0731    0.0668     0.1364
# 53     -0.0023      -0.1405       1.3390        6.9135    0.4767     1.2436
# 54     -0.0422      -1.1716       0.5969        5.7889   -0.1999    -0.9851
# 55     -0.0222      -0.3846       2.2482        6.5486    0.5790     0.8381
# 63   -0.2570    -1.0373    0.1069     0.3129  ...    -0.4649
# 64    1.0419     1.9875   -0.4727    -0.6972  ...    -0.5268
# 65    0.1714     0.8319    0.1381     0.4877  ...     0.9144
# 66    0.0387     0.1158    0.5714     1.2987  ...     0.9526
# 67    0.3738     1.5803    0.1618     0.5110  ...    -1.3993
# 68   -0.3561    -1.4935    0.7143     2.2514  ...    -0.4809
#
#     Overall_ESG_Exposure_coef  Overall_ESG_Exposure_tstat  \
# 33                     0.6969                      0.3768
# 34                     0.8032                      0.8041
# 35                    -3.4786                     -2.0022
# 36                     0.1734                      0.3362
# 37                     0.0389                      0.3076
# 38                     1.1349                      0.2108
# 39                     3.8293                      0.7974
# 40                     3.1576                      1.3885
# 41                    -0.1048                     -0.1724
# 42                     3.5388                      1.4490
# 43                    -0.3818                     -1.4919
# 44                    -0.6361                     -0.9934
# 45                     1.7755                      1.8739
# 46                    -0.8385                     -0.5201
# 47                    -0.7210                     -0.6975
# 48                    -0.2542                     -0.4161
# 49                     1.2972                      0.2400
# 50                     1.0677                      0.6361
# 51                     0.0105                      0.1557
# 52                     0.5020                      0.3682
# 53                     0.0858                      0.7122
# 54                     0.5022                      1.0181
# 55                     0.8962                      0.8483
# 56                     0.3560                      1.5154
# 57                     0.3695                      0.7930
# 58                     0.3154                      0.7540
# 59                    -1.2376                     -0.6360
# 60                   -18.8105                     -1.5135
# 61                    -0.0317                     -0.2903
# 62                    -0.9227                     -0.6859
# 63                     0.1856                      0.7413
# 64                     0.2971                      0.9558
# 65                     1.0030                      0.8336
# 66                     1.4872                      0.8841
# 67                     0.1618                      0.3085
# 68                     0.1622                      0.3446
#
#     Overall_ESG_Sentiment_coef  Overall_ESG_Sentiment_tstat      R2  Adj_R2  \
# 33                     -0.0289                      -0.3905  0.2618  0.1785
# 34                      0.0366                       0.3477  0.5728  0.5246
# 35                     -0.0459                      -0.2135  0.3708  0.2998
# 36                     -0.0220                      -0.2509  0.7704  0.7445
# 37                      0.0911                       0.8783  0.6767  0.6402
# 38                     -0.0851                      -0.7372  0.0551 -0.0515
# 39                     -0.1437                      -1.0578  0.6156  0.5722
# 40                     -0.0763                      -1.1082  0.4511  0.3892
# 41                     -0.1366                      -0.3832  0.4428  0.3799
# 42                     -0.1426                      -0.8290  0.3637  0.2919
# 43                     -0.4056                      -2.2199  0.6133  0.5697
# 44                      0.0067                       0.0754  0.4040  0.3367
# 45                     -0.2474                      -2.8752  0.4200  0.3545
# 46                      0.0252                       0.1730  0.2822  0.2012
# 47                      0.1853                       0.9446  0.5659  0.5169
# 48                     -0.0652                      -0.7329  0.2769  0.1953
# 49                     -0.0323                      -0.3426  0.5667  0.5178
# 50                     -0.0431                      -0.7737  0.4770  0.4179
# 51                     -0.1679                      -0.8405  0.5000  0.4435
# 52                      0.0475                       0.5559  0.1990  0.1086
# 53                     -0.1408                      -1.4023  0.6132  0.5695
# 54                     -0.0045                      -0.0762  0.4999  0.4434
# 55                     -0.1482                      -0.4422  0.5741  0.5261
# 56                     -0.1873                      -1.6163  0.5094  0.4540
# 57                      0.2620                       0.7681  0.4449  0.3822
# 58                     -0.1317                      -0.3348  0.6941  0.6595
# 59                     -0.4450                      -1.7943  0.5989  0.5536
# 60                      0.2438                       1.0166  0.0876 -0.0154
# 61                      0.2054                       2.5760  0.6434  0.6032
# 62                      0.1600                       1.0813  0.4028  0.3353
# 63                      0.0613                       0.6230  0.6900  0.6550
# 64                     -0.3082                      -1.5326  0.4550  0.3935
# 65                     -0.0666                      -0.9033  0.2953  0.2158
# 66                     -0.0272                      -0.2061  0.3659  0.2943
# 67                     -0.2229                      -0.8433  0.5571  0.5071
# 68                     -0.0968                      -1.9964  0.4894  0.4317
#
#     n_obs  Macro_Sector Ticker
# 33     70   Industrials   ABBV
# 34     70   Industrials    ABT
# 35     70   Industrials   ANET
# 36     70   Industrials    APH
# 37     70   Industrials   APTV
# 38     70   Industrials   BIIB
# 39     70   Industrials   BKNG
# 40     70   Industrials    BSX
# 41     70   Industrials     CF
# 42     70   Industrials   CHTR
# 43     70   Industrials    CMI
# 44     70   Industrials    DHR
# 45     70   Industrials     EL
# 46     70   Industrials   FTNT
# 47     70   Industrials     GM
# 48     70   Industrials    HII
# 49     70   Industrials   ISRG
# 50     70   Industrials    JNJ
# 51     70   Industrials     KO
# 52     70   Industrials     LW
# 53     70   Industrials   MCHP
# 54     70   Industrials   MDLZ
# 55     70   Industrials   NCLH
# 56     70   Industrials    PEP
# 57     70   Industrials     PM
# 58     70   Industrials    PPG
# 59     70   Industrials    RCL
# 60     70   Industrials   REGN
# 61     70   Industrials    SWK
# 62     70   Industrials      T
# 63     70   Industrials   TRMB
# 64     70   Industrials    UAL
# 65     70   Industrials     VZ
# 66     70   Industrials   XRAY
# 67     70   Industrials    XYL
# 68     70   Industrials    ZTS
#
# [36 rows x 21 columns]
#
# === Ticker-Level Regression: Consumer ===
#     const_coef  const_tstat  Mkt-RF_coef  Mkt-RF_tstat  SMB_coef  SMB_tstat  \
# 0       0.0151       0.1744       0.9586        3.4241    0.3226     0.6064
# 1      -0.1122      -1.5324       1.3712        7.3774   -0.7317    -1.9343
# 2       0.1250       1.7848       0.6580        5.0681    0.3912     1.5266
# 3      -0.0392      -0.3675       0.7890        4.8158   -0.3887    -1.1946
# 4      -0.0089      -0.2221       1.4412        7.3133    0.0596     0.1534
# 5       0.1261       2.9347       1.0933        8.2567   -0.3484    -1.3206
# 6      -0.0093      -0.4412       1.0011        6.4578    0.1294     0.4213
# 7      -0.0313      -0.9421       0.7547        3.2058    0.9160     1.9620
# 8       0.0236       0.6334       1.1499        7.6637   -0.1213    -0.4046
# 9      -0.3047      -1.0052       1.2507        7.6080    0.4656     1.4076
# 10      0.0003       0.0126       1.2633        7.3871   -0.1809    -0.5373
# 11      0.0328       0.5177       1.3966        6.1644    1.1824     2.6053
# 12     -0.0020      -0.0793       0.9218        6.0943    0.2844     0.9439
# 13      0.0692       1.1250       0.8606        5.8468   -0.1284    -0.4462
# 14      0.0111       0.2212       1.7551        4.0623    1.6662     1.9899
# 15      0.0186       0.7020       1.1612        7.2254    0.2732     0.8670
# 16      0.0087       0.1623       1.0146        5.8447    0.0759     0.2179
# 17     -0.0149      -0.4759       0.8788        4.7551   -0.2560    -0.7039
# 18      0.0337       1.5208       0.5980        5.0589   -0.1962    -0.8581
# 19     -0.0320      -0.1637       1.6119        5.8367    0.5097     0.9117
#
#     HML_coef  HML_tstat  RMW_coef  RMW_tstat  ...  CMA_tstat  \
# 0     0.8238     1.6828    0.4262     0.6695  ...    -0.3042
# 1    -0.1687    -0.5182    0.0183     0.0425  ...    -0.8194
# 2    -0.0666    -0.3025    0.4985     1.7088  ...    -0.4408
# 3    -0.5020    -1.7922    0.2289     0.6177  ...     2.1874
# 4     0.1614     0.4920    0.5093     1.1287  ...     0.4780
# 5    -0.4086    -1.8559   -0.1480    -0.4865  ...    -2.3468
# 6     0.1032     0.3917    0.0425     0.1200  ...    -0.3239
# 7    -0.3501    -0.8858    0.9707     1.8166  ...     1.3349
# 8     0.6728     2.6421   -0.0751    -0.2207  ...    -1.5275
# 9     0.0286     0.1037    0.4734     1.2690  ...    -0.7415
# 10    0.4403     1.5372   -0.4559    -1.1716  ...    -1.6893
# 11   -0.2681    -0.6764    0.6685     1.3107  ...     0.1119
# 12    0.4173     1.6480   -0.0311    -0.0899  ...     0.9388
# 13    0.0204     0.0830    0.5111     1.5251  ...     0.3308
# 14   -0.2311    -0.3251    0.0034     0.0036  ...    -0.6150
# 15    0.4846     1.8369   -0.1960    -0.5473  ...    -1.0005
# 16    0.0933     0.3228    0.2158     0.5414  ...    -0.0268
# 17   -0.4715    -1.5097   -0.6631    -1.5909  ...     0.7049
# 18   -0.3575    -1.8311    0.2454     0.9308  ...     1.8874
# 19    0.7596     1.5719    0.4997     0.7950  ...    -1.1464
#
#     Overall_ESG_Exposure_coef  Overall_ESG_Exposure_tstat  \
# 0                     -0.1655                     -0.1673
# 1                      4.7442                      1.5834
# 2                     -2.7339                     -0.7826
# 3                      2.6106                      0.4426
# 4                      0.3269                      0.3994
# 5                     -4.0214                     -2.5083
# 6                      0.2655                      0.2608
# 7                      0.5316                      0.9812
# 8                     -0.4596                     -0.4977
# 9                      8.3689                      0.8457
# 10                    -2.7534                     -2.2255
# 11                    -0.8382                     -0.6600
# 12                     0.4194                      0.5395
# 13                    -1.3314                     -0.9294
# 14                     1.4558                      1.0500
# 15                    -1.8565                     -1.0576
# 16                     0.2591                      0.1188
# 17                    -0.6386                     -0.3170
# 18                     0.3212                      0.2443
# 19                     0.5733                      0.0978
#
#     Overall_ESG_Sentiment_coef  Overall_ESG_Sentiment_tstat      R2  Adj_R2  \
# 0                      -0.1297                      -1.5682  0.3083  0.2429
# 1                       0.1101                       0.7053  0.5385  0.4864
# 2                      -0.2646                      -1.4110  0.4423  0.3793
# 3                      -0.0243                      -0.1403  0.3411  0.2668
# 4                      -0.0686                      -0.8010  0.5444  0.4930
# 5                      -0.2575                      -1.6449  0.6619  0.6237
# 6                      -0.0116                      -0.1751  0.4917  0.4343
# 7                      -0.0374                      -0.2429  0.2992  0.2201
# 8                       0.0337                       0.4431  0.6025  0.5577
# 9                       0.5028                       1.0648  0.6232  0.5807
# 10                      0.3297                       2.1417  0.5719  0.5235
# 11                     -0.0322                      -0.3250  0.5530  0.5025
# 12                     -0.0562                      -0.4240  0.5320  0.4792
# 13                     -0.0395                      -0.4230  0.4420  0.3790
# 14                     -0.1321                      -1.1023  0.4012  0.3336
# 15                     -0.0120                      -0.2718  0.5993  0.5540
# 16                     -0.0360                      -0.6131  0.4358  0.3721
# 17                      0.0982                       1.1366  0.3502  0.2768
# 18                     -0.1297                      -0.8533  0.3698  0.2986
# 19                      0.0027                       0.0195  0.5142  0.4594
#
#     n_obs  Macro_Sector Ticker
# 0      82      Consumer    AAP
# 1      70      Consumer   ADBE
# 2      70      Consumer    ADP
# 3      70      Consumer   AKAM
# 4      70      Consumer    BBY
# 5      70      Consumer   CDNS
# 6      70      Consumer   CTSH
# 7      70      Consumer   DLTR
# 8      70      Consumer    HLT
# 9      70      Consumer    IQV
# 10     70      Consumer     IT
# 11     70      Consumer    KMX
# 12     70      Consumer    OMC
# 13     70      Consumer   ORLY
# 14     70      Consumer   PENN
# 15     70      Consumer    RHI
# 16     70      Consumer   ROST
# 17     70      Consumer   TTWO
# 18     70      Consumer    WMT
# 19     70      Consumer   WYNN
#
# [20 rows x 21 columns]
#
# === Ticker-Level Regression: Energy & Utilities ===
#     const_coef  const_tstat  Mkt-RF_coef  Mkt-RF_tstat  SMB_coef  SMB_tstat  \
# 20      0.0150       0.2928       0.5905        4.2181   -0.2982    -1.0729
# 21     -0.0475      -0.9226       1.0694        4.4330    0.2075     0.4284
# 22      0.0143       0.8464       1.4523        7.7504    0.1165     0.3063
# 23     -0.0055      -0.1365       0.5715        3.8189   -0.1349    -0.4515
# 24     -0.0016      -0.0352       0.5438        4.1842   -0.1665    -0.6537
# 25      0.0130       0.2339       0.4359        2.8596    0.1288     0.4204
# 26      0.0031       0.1070       0.5331        4.5137   -0.3662    -1.5702
# 27      0.0087       0.3503       0.5851        4.3971   -0.1311    -0.5019
# 28     -0.1168      -1.5242       0.5131        3.2404   -0.0615    -0.1903
# 29     -0.0307      -0.9346       0.8116        7.0164   -0.0580    -0.2520
# 30     -0.0361      -0.4220       1.5644        7.3157    0.1039     0.2445
# 31     -0.0143      -0.3672       0.4711        3.5728   -0.3492    -1.3407
# 32     -0.3998      -1.6659       1.1185        6.9717   -0.3420    -1.0959
#
#     HML_coef  HML_tstat  RMW_coef  RMW_tstat  ...  CMA_tstat  \
# 20    0.1033     0.4372    0.1046     0.3311  ...     1.1275
# 21    0.0436     0.1076   -0.2866    -0.5221  ...     1.1843
# 22   -0.4853    -1.4638    0.3420     0.8067  ...     0.0144
# 23    0.1638     0.6438    0.0469     0.1403  ...     0.6694
# 24    0.1601     0.7279    0.4391     1.5316  ...     1.4433
# 25    0.0979     0.3641    0.3929     1.1404  ...     0.0458
# 26    0.2969     1.4841    0.0251     0.0943  ...     1.5892
# 27    0.0470     0.2086    0.4157     1.3941  ...     0.9741
# 28    0.1668     0.6032    0.5906     1.6181  ...     1.0269
# 29    0.1600     0.8320    0.4181     1.5588  ...     1.9380
# 30    1.6731     4.6839   -0.5069    -1.0439  ...     0.5955
# 31   -0.0327    -0.1454    0.3938     1.3136  ...     1.7376
# 32    0.7354     2.7816   -0.0211    -0.0583  ...     0.5061
#
#     Overall_ESG_Exposure_coef  Overall_ESG_Exposure_tstat  \
# 20                    -0.3989                     -0.8799
# 21                     0.2747                      1.2028
# 22                    12.5560                      0.6564
# 23                     0.0635                      0.6479
# 24                     0.0370                      0.2141
# 25                    -0.5009                     -1.2790
# 26                    -0.0992                     -0.9657
# 27                    -0.0414                     -0.5366
# 28                     0.1157                      0.8187
# 29                     0.2589                      1.2337
# 30                     0.0000                      0.0001
# 31                     0.0227                      0.4014
# 32                     0.9861                      1.5617
#
#     Overall_ESG_Sentiment_coef  Overall_ESG_Sentiment_tstat      R2  Adj_R2  \
# 20                      0.3290                       1.0142  0.2797  0.1983
# 21                     -0.4668                      -1.6340  0.3383  0.2636
# 22                     -0.3882                      -0.7681  0.5691  0.5204
# 23                     -0.0643                      -0.3936  0.2547  0.1706
# 24                     -0.0562                      -0.4342  0.3570  0.2845
# 25                      0.3245                       1.9358  0.2414  0.1558
# 26                      0.0884                       1.3490  0.3824  0.3127
# 27                      0.0293                       0.4847  0.3223  0.2458
# 28                      0.4066                       1.5911  0.2664  0.1836
# 29                     -0.1623                      -1.1022  0.5454  0.4941
# 30                      0.1476                       0.6132  0.7052  0.6719
# 31                     -0.0154                      -0.1193  0.2748  0.1930
# 32                      0.3728                       1.8077  0.5631  0.5138
#
#     n_obs        Macro_Sector Ticker
# 20     70  Energy & Utilities    AEP
# 21     70  Energy & Utilities    AES
# 22     70  Energy & Utilities    EFX
# 23     70  Energy & Utilities   EVRG
# 24     70  Energy & Utilities    EXC
# 25     70  Energy & Utilities     FE
# 26     70  Energy & Utilities     NI
# 27     70  Energy & Utilities    PEG
# 28     70  Energy & Utilities    PNW
# 29     70  Energy & Utilities    PPL
# 30     70  Energy & Utilities    SLB
# 31     70  Energy & Utilities    WEC
# 32     70  Energy & Utilities    WMB
#
# [13 rows x 21 columns]
#
# Done! All tables printed.

# %%
import pandas as pd
import statsmodels.api as sm

# Load your data from Excel
df = pd.read_excel(
    'climate_final_with_ff5_and_excess_return.xlsx',
    sheet_name='climate_final_with_ff5_and_exce',
    parse_dates=['date']
)

# Define your factor lists
fama_french_factors = ['Mkt-RF', 'SMB', 'HML', 'RMW', 'CMA']
env_factors = ['Overall_ESG_Exposure', 'Overall_ESG_Sentiment']

# Helper function to run regressions and collect results
def run_regression(y, X):
    X = sm.add_constant(X)
    model = sm.OLS(y, X).fit()
    results = {}
    for var in X.columns:
        results[f'{var}_coef']   = model.params[var]
        results[f'{var}_tstat']  = model.tvalues[var]
    results['R2']     = model.rsquared
    results['Adj_R2'] = model.rsquared_adj
    return results

# --- 1. Macro‐Sector Level Regressions ---
sector_results_fama     = []
sector_results_fama_env = []

for sector, group in df.groupby('Macro_Sector'):
    # Fama‐French only
    res_fama = run_regression(group['excess_RET'], group[fama_french_factors])
    res_fama['Macro_Sector'] = sector
    sector_results_fama.append(res_fama)
    # Fama‐French + ENV
    res_fama_env = run_regression(
        group['excess_RET'],
        group[fama_french_factors + env_factors]
    )
    res_fama_env['Macro_Sector'] = sector
    sector_results_fama_env.append(res_fama_env)

sector_df_fama     = pd.DataFrame(sector_results_fama)
sector_df_fama_env = pd.DataFrame(sector_results_fama_env)

# --- 2. Ticker‐Level Regressions (within each Macro Sector) ---
ticker_results_fama     = []
ticker_results_fama_env = []

for (sector, ticker), group in df.groupby(['Macro_Sector', 'TICKER']):
    # Fama‐French only
    res_t_fama = run_regression(group['excess_RET'], group[fama_french_factors])
    res_t_fama['Macro_Sector'] = sector
    res_t_fama['Ticker']       = ticker
    ticker_results_fama.append(res_t_fama)
    # Fama‐French + ENV
    res_t_fama_env = run_regression(
        group['excess_RET'],
        group[fama_french_factors + env_factors]
    )
    res_t_fama_env['Macro_Sector'] = sector
    res_t_fama_env['Ticker']       = ticker
    ticker_results_fama_env.append(res_t_fama_env)

ticker_df_fama     = pd.DataFrame(ticker_results_fama)
ticker_df_fama_env = pd.DataFrame(ticker_results_fama_env)

# --- 3. Pretty‐printing ---
print("\n=== Macro‐Sector Level: FF5 Only ===")
print(sector_df_fama.round(4))

print("\n=== Macro‐Sector Level: FF5 + ENV ===")
print(sector_df_fama_env.round(4))

for name, df_t in [
    ("Industrials", ticker_df_fama[ticker_df_fama['Macro_Sector']=='Industrials']),
    ("Consumer",    ticker_df_fama[ticker_df_fama['Macro_Sector']=='Consumer']),
    ("Energy & Utilities", ticker_df_fama[ticker_df_fama['Macro_Sector']=='Energy & Utilities'])
]:
    print(f"\n=== Ticker‐Level ({name}): FF5 Only ===")
    print(df_t.round(4))

for name, df_t in [
    ("Industrials", ticker_df_fama_env[ticker_df_fama_env['Macro_Sector']=='Industrials']),
    ("Consumer",    ticker_df_fama_env[ticker_df_fama_env['Macro_Sector']=='Consumer']),
    ("Energy & Utilities", ticker_df_fama_env[ticker_df_fama_env['Macro_Sector']=='Energy & Utilities'])
]:
    print(f"\n=== Ticker‐Level ({name}): FF5 + ENV ===")
    print(df_t.round(4))

print("\nDone! All tables printed.")
# Out:
# === Macro‐Sector Level: FF5 Only ===
#    const_coef  const_tstat  Mkt-RF_coef  Mkt-RF_tstat  SMB_coef  SMB_tstat  \
# 0     -0.0034      -1.4755       1.0880       22.7770    0.2473     2.6322
# 1     -0.0033      -1.3986       0.7781       16.1851   -0.1016    -1.0700
# 2     -0.0028      -1.6424       0.9543       27.3059    0.1912     2.7711
#
#    HML_coef  HML_tstat  RMW_coef  RMW_tstat  CMA_coef  CMA_tstat      R2  \
# 0    0.0279     0.3514    0.2349     2.1803   -0.0072    -0.0639  0.3478
# 1    0.2424     3.0405    0.1790     1.6497    0.3939     3.4795  0.2976
# 2    0.1192     2.0578    0.2319     2.9392    0.1330     1.6157  0.3019
#
#    Adj_R2        Macro_Sector
# 0  0.3455            Consumer
# 1  0.2937  Energy & Utilities
# 2  0.3005         Industrials
#
# === Macro‐Sector Level: FF5 + ENV ===
#    const_coef  const_tstat  Mkt-RF_coef  Mkt-RF_tstat  SMB_coef  SMB_tstat  \
# 0      0.0032       0.5697       1.0891       22.7940    0.2452     2.6090
# 1     -0.0043      -0.6139       0.7790       16.1943   -0.0974    -1.0245
# 2      0.0010       0.2788       0.9554       27.3364    0.1875     2.7178
#
#    HML_coef  HML_tstat  RMW_coef  RMW_tstat  CMA_coef  CMA_tstat  \
# 0    0.0284     0.3581    0.2330     2.1615   -0.0107    -0.0946
# 1    0.2354     2.9407    0.1791     1.6488    0.4011     3.5349
# 2    0.1218     2.1013    0.2290     2.9023    0.1245     1.5114
#
#    Overall_ESG_Exposure_coef  Overall_ESG_Exposure_tstat  \
# 0                    -0.1212                     -1.1132
# 1                    -0.0096                     -0.6000
# 2                     0.0117                      0.6152
#
#    Overall_ESG_Sentiment_coef  Overall_ESG_Sentiment_tstat      R2  Adj_R2  \
# 0                     -0.0124                      -0.8517  0.3487  0.3454
# 1                      0.0173                       0.8047  0.2985  0.2931
# 2                     -0.0174                      -1.7067  0.3029  0.3009
#
#          Macro_Sector
# 0            Consumer
# 1  Energy & Utilities
# 2         Industrials
#
# === Ticker‐Level (Industrials): FF5 Only ===
#     const_coef  const_tstat  Mkt-RF_coef  Mkt-RF_tstat  SMB_coef  SMB_tstat  \
# 33      0.0077       0.9729       0.5335        3.2703    0.3315     1.0292
# 34     -0.0043      -0.8403       0.8567        8.1612    0.0185     0.0893
# 35      0.0131       1.0710       1.2030        4.7532   -0.5050    -1.0106
# 36      0.0023       0.4797       1.1470       11.7855    0.0678     0.3527
# 37     -0.0195      -2.0399       1.4773        7.4858    1.3933     3.5761
# 38     -0.0080      -0.6347      -0.0284       -0.1085    0.6116     1.1847
# 39      0.0042       0.5374       1.3599        8.3553   -0.3326    -1.0351
# 40      0.0014       0.2168       0.8299        6.4302   -0.5624    -2.2073
# 41      0.0084       0.7988       0.9856        4.5183    0.5210     1.2099
# 42     -0.0095      -0.8796       0.8567        3.8256    0.6947     1.5714
# 43      0.0053       0.8107       1.0056        7.4448    0.1058     0.3968
# 44      0.0008       0.1053       0.7915        5.3520    0.0564     0.1932
# 45     -0.0212      -1.9913       0.8442        3.8334    0.8874     2.0411
# 46      0.0177       1.4113       1.0551        4.0717    0.1359     0.2656
# 47     -0.0021      -0.2177       1.3099        6.4883    0.6213     1.5587
# 48     -0.0011      -0.1115       0.5051        2.5966    0.1587     0.4131
# 49     -0.0005      -0.0579       1.5108        8.7157   -0.5282    -1.5433
# 50     -0.0066      -1.4080       0.5872        6.0449    0.1144     0.5966
# 51     -0.0035      -0.7298       0.5790        5.8006   -0.3021    -1.5330
# 52     -0.0025      -0.2218       0.7253        3.0796    0.1345     0.2893
# 53     -0.0076      -0.8122       1.3415        6.9230    0.5973     1.5613
# 54     -0.0062      -1.2832       0.5919        5.8909   -0.1639    -0.8262
# 55     -0.0085      -0.5202       2.2891        6.7758    0.4526     0.6786
# 56     -0.0043      -1.0063       0.5185        5.9225   -0.0547    -0.3166
# 57      0.0013       0.2187       0.5896        4.6984   -0.0083    -0.0335
# 58     -0.0135      -2.2339       1.1108        8.9312    0.1897     0.7724
# 59      0.0069       0.4458       2.2482        7.0788    0.1133     0.1807
# 60      0.0063       0.5429       0.2456        1.0303   -0.0205    -0.0435
# 61     -0.0162      -1.8261       1.0015        5.4635    0.9484     2.6208
# 62     -0.0039      -0.5945       0.6113        4.4799   -0.2880    -1.0690
# 63     -0.0034      -0.4869       1.3435        9.1884    0.6662     2.3080
# 65    0.1686     0.8332    0.0472     0.1713    0.2144     0.7460  0.2715
# 66   -0.0566    -0.1769    0.6145     1.4123    0.5454     1.2016  0.3542
# 67    0.3101     1.3456    0.2116     0.6745   -0.3358    -1.0260  0.5430
# 68   -0.4795    -2.0516    0.7708     2.4227   -0.0573    -0.1726  0.4564
#
#     Adj_R2 Macro_Sector Ticker
# 33  0.2011  Industrials   ABBV
# 34  0.5259  Industrials    ABT
# 35  0.2634  Industrials   ANET
# 36  0.7508  Industrials    APH
# 37  0.6471  Industrials   APTV
# 38 -0.0368  Industrials   BIIB
# 39  0.5632  Industrials   BKNG
# 40  0.3703  Industrials    BSX
# 41  0.3974  Industrials     CF
# 42  0.2762  Industrials   CHTR
# 43  0.5497  Industrials    CMI
# 44  0.3308  Industrials    DHR
# 45  0.2894  Industrials     EL
# 46  0.2219  Industrials   FTNT
# 47  0.5177  Industrials     GM
# 48  0.2127  Industrials    HII
# 49  0.5302  Industrials   ISRG
# 50  0.4306  Industrials    JNJ
# 51  0.4397  Industrials     KO
# 52  0.1313  Industrials     LW
# 53  0.5579  Industrials   MCHP
# 54  0.4515  Industrials   MDLZ
# 55  0.5336  Industrials   NCLH
# 56  0.4422  Industrials    PEP
# 57  0.3924  Industrials     PM
# 58  0.6552  Industrials    PPG
# 59  0.5435  Industrials    RCL
# 60 -0.0272  Industrials   REGN
# 61  0.5270  Industrials    SWK
# 62  0.3312  Industrials      T
# 63  0.6624  Industrials   TRMB
# 64  0.3877  Industrials    UAL
# 65  0.2145  Industrials     VZ
# 66  0.3037  Industrials   XRAY
# 67  0.5073  Industrials    XYL
# 68  0.4140  Industrials    ZTS
#
# === Ticker‐Level (Consumer): FF5 Only ===
#     const_coef  const_tstat  Mkt-RF_coef  Mkt-RF_tstat  SMB_coef  SMB_tstat  \
# 0      -0.0220      -1.6720       0.9624        3.4305    0.5160     0.9938
# 1      -0.0071      -0.7856       1.3625        7.3127   -0.5873    -1.5967
# 2       0.0019       0.3013       0.6385        4.9132    0.3373     1.3147
# 3      -0.0066      -0.8529       0.8056        5.0482   -0.3907    -1.2401
# 4      -0.0088      -0.9328       1.4468        7.4436    0.0534     0.1392
# 5       0.0129       1.9561       1.0531        7.7156   -0.2162    -0.8022
# 6      -0.0073      -0.9954       1.0004        6.6033    0.1171     0.3917
# 7      -0.0128      -1.1372       0.7562        3.2527    0.9583     2.0879
# 8       0.0060       0.8419       1.1476        7.7644   -0.1377    -0.4718
# 9      -0.0084      -1.0749       1.2507        7.7502    0.5708     1.7917
# 10      0.0086       1.0003       1.1961        6.7704   -0.0831    -0.2382
# 11     -0.0069      -0.6415       1.4028        6.2899    1.1918     2.7068
# 12     -0.0027      -0.3756       0.9139        6.1582    0.2665     0.9095
# 13      0.0041       0.5827       0.8438        5.8465   -0.1103    -0.3870
# 14     -0.0021      -0.1047       1.7546        4.1712    1.7748     2.1371
# 15     -0.0059      -0.7788       1.1412        7.2879    0.3233     1.0457
# 16     -0.0032      -0.3872       1.0226        6.0061    0.0619     0.1843
# 17      0.0050       0.5637       0.8947        4.8966   -0.2251    -0.6239
# 18      0.0064       1.1367       0.6098        5.2867   -0.2106    -0.9247
# 19     -0.0150      -1.1374       1.6127        5.9373    0.5188     0.9674
#
#     HML_coef  HML_tstat  RMW_coef  RMW_tstat  CMA_coef  CMA_tstat      R2  \
# 0     0.6401     1.3485    0.6152     0.9844    0.1071     0.1587  0.2850
# 1    -0.2716    -0.8792    0.1533     0.3646   -0.2097    -0.4779  0.5194
# 2     0.0184     0.0856    0.5227     1.7818   -0.0928    -0.3033  0.4143
# 3    -0.5384    -2.0344    0.1908     0.5296    0.8657     2.3035  0.3363
# 4     0.1390     0.4312    0.4563     1.0398    0.1948     0.4256  0.5397
# 5    -0.4699    -2.0761   -0.0039    -0.0127   -0.5257    -1.6356  0.6227
# 6     0.1146     0.4563    0.0280     0.0819   -0.1463    -0.4100  0.4911
# 7    -0.4207    -1.0912    0.9724     1.8528    0.8955     1.6358  0.2882
# 8     0.6948     2.8347   -0.0771    -0.2312   -0.5805    -1.6677  0.6009
# 9    -0.0512    -0.1912    0.5697     1.5639   -0.1916    -0.5042  0.6132
# 10    0.5073     1.7316   -0.2363    -0.5925   -0.5253    -1.2626  0.5162
# 11   -0.2772    -0.7495    0.6729     1.3366    0.0327     0.0623  0.5498
# 12    0.4286     1.7416   -0.0679    -0.2025    0.3417     0.9777  0.5293
# 13    0.0560     0.2338    0.5797     1.7793    0.1302     0.3832  0.4317
# 14   -0.3875    -0.5556    0.0775     0.0816   -0.2571    -0.2596  0.3839
# 15    0.4569     1.7596   -0.1546    -0.4373   -0.2770    -0.7512  0.5919
# 16    0.0830     0.2939    0.1933     0.5030    0.0023     0.0056  0.4323
# 17   -0.5243    -1.7305   -0.6463    -1.5669    0.3509     0.8155  0.3364
# 18   -0.3640    -1.9032    0.2023     0.7770    0.4496     1.6552  0.3531
# 19    0.7469     1.6583    0.4996     0.8148   -0.7670    -1.1990  0.5141
#
#     Adj_R2 Macro_Sector Ticker
# 0   0.2379     Consumer    AAP
# 1   0.4818     Consumer   ADBE
# 2   0.3685     Consumer    ADP
# 3   0.2844     Consumer   AKAM
# 4   0.5038     Consumer    BBY
# 5   0.5932     Consumer   CDNS
# 6   0.4513     Consumer   CTSH
# 7   0.2325     Consumer   DLTR
# 8   0.5697     Consumer    HLT
# 9   0.5829     Consumer    IQV
# 10  0.4784     Consumer     IT
# 11  0.5147     Consumer    KMX
# 12  0.4925     Consumer    OMC
# 13  0.3873     Consumer   ORLY
# 14  0.3358     Consumer   PENN
# 15  0.5601     Consumer    RHI
# 16  0.3880     Consumer   ROST
# 17  0.2846     Consumer   TTWO
# 18  0.3026     Consumer    WMT
# 19  0.4762     Consumer   WYNN
#
# === Ticker‐Level (Energy & Utilities): FF5 Only ===
#     const_coef  const_tstat  Mkt-RF_coef  Mkt-RF_tstat  SMB_coef  SMB_tstat  \
# 20     -0.0032      -0.4823       0.5653        4.1319   -0.3172    -1.1742
# 21     -0.0078      -0.6717       1.0513        4.3747    0.3465     0.7303
# 22     -0.0021      -0.2375       1.4406        7.7466    0.1185     0.3229
# 23     -0.0026      -0.3672       0.5871        4.0260   -0.1278    -0.4438
# 24     -0.0052      -0.8531       0.5332        4.2640   -0.1545    -0.6259
# 25     -0.0034      -0.4594       0.4101        2.6725   -0.0012    -0.0040
# 26     -0.0003      -0.0480       0.5517        4.6970   -0.4235    -1.8265
# 27     -0.0015      -0.2394       0.5805        4.4870   -0.1390    -0.5444
# 28     -0.0063      -0.8176       0.4977        3.1378   -0.0945    -0.3017
# 29     -0.0073      -1.3043       0.8138        7.0640   -0.0959    -0.4215
# 30     -0.0043      -0.4248       1.5386        7.3064    0.1825     0.4389
# 31     -0.0035      -0.5544       0.4736        3.6513   -0.3285    -1.2829
# 32      0.0051       0.6685       1.0719        6.7522   -0.2856    -0.9113
#
#     HML_coef  HML_tstat  RMW_coef  RMW_tstat  CMA_coef  CMA_tstat      R2  \
# 20    0.1429     0.6298    0.1011     0.3273    0.4340     1.3469  0.2673
# 21   -0.0963    -0.2417   -0.1918    -0.3536    1.0256     1.8123  0.3098
# 22   -0.4705    -1.5256    0.3744     0.8919    0.0786     0.1796  0.5598
# 23    0.1422     0.5881    0.0662     0.2011    0.2666     0.7763  0.2479
# 24    0.1551     0.7477    0.4423     1.5667    0.4913     1.6683  0.3550
# 25    0.2807     1.1034    0.3809     1.0996   -0.0770    -0.2131  0.1955
# 26    0.3376     1.7332   -0.0067    -0.0252    0.3491     1.2622  0.3552
# 27    0.0716     0.3337    0.4230     1.4481    0.2746     0.9013  0.3187
# 28    0.1627     0.6185    0.4731     1.3210    0.3846     1.0297  0.2357
# 29    0.1622     0.8493    0.3413     1.3124    0.5077     1.8715  0.5340
# 30    1.6363     4.6860   -0.4144    -0.8717    0.4850     0.9780  0.6994
# 31   -0.0753    -0.3502    0.3801     1.2979    0.5984     1.9592  0.2682
# 32    0.7018     2.6661   -0.0418    -0.1168    0.3024     0.8089  0.5398
#
#     Adj_R2        Macro_Sector Ticker
# 20  0.2101  Energy & Utilities    AEP
# 21  0.2558  Energy & Utilities    AES
# 22  0.5254  Energy & Utilities    EFX
# 23  0.1891  Energy & Utilities   EVRG
# 24  0.3047  Energy & Utilities    EXC
# 25  0.1326  Energy & Utilities     FE
# 26  0.3048  Energy & Utilities     NI
# 27  0.2655  Energy & Utilities    PEG
# 28  0.1760  Energy & Utilities    PNW
# 29  0.4976  Energy & Utilities    PPL
# 30  0.6759  Energy & Utilities    SLB
# 31  0.2110  Energy & Utilities    WEC
# 32  0.5038  Energy & Utilities    WMB
#
# === Ticker‐Level (Industrials): FF5 + ENV ===
#     const_coef  const_tstat  Mkt-RF_coef  Mkt-RF_tstat  SMB_coef  SMB_tstat  \
# 33      0.0102       0.2833       0.5299        3.1539    0.3037     0.9131
# 34     -0.0447      -1.0647       0.8285        7.7314    0.0037     0.0176
# 35      0.0699       1.5902       1.2619        5.0386   -0.4179    -0.8495
# 36      0.0024       0.0452       1.1519       11.6496    0.0958     0.4801
# 37     -0.0398      -1.2924       1.4432        7.0912    1.3633     3.4400
# 38     -0.0108      -0.3095      -0.0078       -0.0296    0.5252     0.9721
# 34                      0.0366                       0.3477  0.5728  0.5246
# 35                     -0.0459                      -0.2135  0.3708  0.2998
# 36                     -0.0220                      -0.2509  0.7704  0.7445
# 37                      0.0911                       0.8783  0.6767  0.6402
# 38                     -0.0851                      -0.7372  0.0551 -0.0515
# 39                     -0.1437                      -1.0578  0.6156  0.5722
# 40                     -0.0763                      -1.1082  0.4511  0.3892
# 41                     -0.1366                      -0.3832  0.4428  0.3799
# 42                     -0.1426                      -0.8290  0.3637  0.2919
# 43                     -0.4056                      -2.2199  0.6133  0.5697
# 44                      0.0067                       0.0754  0.4040  0.3367
# 45                     -0.2474                      -2.8752  0.4200  0.3545
# 46                      0.0252                       0.1730  0.2822  0.2012
# 47                      0.1853                       0.9446  0.5659  0.5169
# 48                     -0.0652                      -0.7329  0.2769  0.1953
# 49                     -0.0323                      -0.3426  0.5667  0.5178
# 50                     -0.0431                      -0.7737  0.4770  0.4179
# 51                     -0.1679                      -0.8405  0.5000  0.4435
# 52                      0.0475                       0.5559  0.1990  0.1086
# 53                     -0.1408                      -1.4023  0.6132  0.5695
# 54                     -0.0045                      -0.0762  0.4999  0.4434
# 55                     -0.1482                      -0.4422  0.5741  0.5261
# 56                     -0.1873                      -1.6163  0.5094  0.4540
# 57                      0.2620                       0.7681  0.4449  0.3822
# 58                     -0.1317                      -0.3348  0.6941  0.6595
# 59                     -0.4450                      -1.7943  0.5989  0.5536
# 60                      0.2438                       1.0166  0.0876 -0.0154
# 61                      0.2054                       2.5760  0.6434  0.6032
# 62                      0.1600                       1.0813  0.4028  0.3353
# 63                      0.0613                       0.6230  0.6900  0.6550
# 64                     -0.3082                      -1.5326  0.4550  0.3935
# 65                     -0.0666                      -0.9033  0.2953  0.2158
# 66                     -0.0272                      -0.2061  0.3659  0.2943
# 67                     -0.2229                      -0.8433  0.5571  0.5071
# 68                     -0.0968                      -1.9964  0.4894  0.4317
#
#    Macro_Sector Ticker
# 33  Industrials   ABBV
# 34  Industrials    ABT
# 35  Industrials   ANET
# 36  Industrials    APH
# 37  Industrials   APTV
# 38  Industrials   BIIB
# 39  Industrials   BKNG
# 40  Industrials    BSX
# 41  Industrials     CF
# 42  Industrials   CHTR
# 43  Industrials    CMI
# 44  Industrials    DHR
# 45  Industrials     EL
# 46  Industrials   FTNT
# 47  Industrials     GM
# 48  Industrials    HII
# 49  Industrials   ISRG
# 50  Industrials    JNJ
# 51  Industrials     KO
# 52  Industrials     LW
# 53  Industrials   MCHP
# 54  Industrials   MDLZ
# 55  Industrials   NCLH
# 56  Industrials    PEP
# 57  Industrials     PM
# 58  Industrials    PPG
# 59  Industrials    RCL
# 60  Industrials   REGN
# 61  Industrials    SWK
# 62  Industrials      T
# 63  Industrials   TRMB
# 64  Industrials    UAL
# 65  Industrials     VZ
# 66  Industrials   XRAY
# 67  Industrials    XYL
# 68  Industrials    ZTS
#
# === Ticker‐Level (Consumer): FF5 + ENV ===
#     const_coef  const_tstat  Mkt-RF_coef  Mkt-RF_tstat  SMB_coef  SMB_tstat  \
# 0       0.0151       0.1744       0.9586        3.4241    0.3226     0.6064
overall_ESG_Exposure_coef  Overall_ESG_Exposure_tstat  \
# 0                     -0.1655                     -0.1673
# 1                      4.7442                      1.5834
# 2                     -2.7339                     -0.7826
# 3                      2.6106                      0.4426
# 4                      0.3269                      0.3994
# 5                     -4.0214                     -2.5083
# 6                      0.2655                      0.2608
# 7                      0.5316                      0.9812
# 8                     -0.4596                     -0.4977
# 9                      8.3689                      0.8457
# 10                    -2.7534                     -2.2255
# 11                    -0.8382                     -0.6600
# 12                     0.4194                      0.5395
# 13                    -1.3314                     -0.9294
# 14                     1.4558                      1.0500
# 15                    -1.8565                     -1.0576
# 16                     0.2591                      0.1188
# 17                    -0.6386                     -0.3170
# 18                     0.3212                      0.2443
# 19                     0.5733                      0.0978
#
#     Overall_ESG_Sentiment_coef  Overall_ESG_Sentiment_tstat      R2  Adj_R2  \
# 0                      -0.1297                      -1.5682  0.3083  0.2429
# 1                       0.1101                       0.7053  0.5385  0.4864
# 2                      -0.2646                      -1.4110  0.4423  0.3793
# 3                      -0.0243                      -0.1403  0.3411  0.2668
# 4                      -0.0686                      -0.8010  0.5444  0.4930
# 5                      -0.2575                      -1.6449  0.6619  0.6237
# 6                      -0.0116                      -0.1751  0.4917  0.4343
# 7                      -0.0374                      -0.2429  0.2992  0.2201
# 8                       0.0337                       0.4431  0.6025  0.5577
# 9                       0.5028                       1.0648  0.6232  0.5807
# 10                      0.3297                       2.1417  0.5719  0.5235
# 11                     -0.0322                      -0.3250  0.5530  0.5025
# 12                     -0.0562                      -0.4240  0.5320  0.4792
# 13                     -0.0395                      -0.4230  0.4420  0.3790
# 14                     -0.1321                      -1.1023  0.4012  0.3336
# 15                     -0.0120                      -0.2718  0.5993  0.5540
# 16                     -0.0360                      -0.6131  0.4358  0.3721
# 17                      0.0982                       1.1366  0.3502  0.2768
# 18                     -0.1297                      -0.8533  0.3698  0.2986
# 19                      0.0027                       0.0195  0.5142  0.4594
#
#    Macro_Sector Ticker
# 0      Consumer    AAP
# 1      Consumer   ADBE
# 2      Consumer    ADP
# 3      Consumer   AKAM
# 4      Consumer    BBY
# 5      Consumer   CDNS
# 6      Consumer   CTSH
# 7      Consumer   DLTR
# 8      Consumer    HLT
# 9      Consumer    IQV
# 10     Consumer     IT
# 11     Consumer    KMX
# 12     Consumer    OMC
# 13     Consumer   ORLY
# 14     Consumer   PENN
# 15     Consumer    RHI
# 16     Consumer   ROST
# 17     Consumer   TTWO
# 18     Consumer    WMT
# 19     Consumer   WYNN
#
# === Ticker‐Level (Energy & Utilities): FF5 + ENV ===
#     const_coef  const_tstat  Mkt-RF_coef  Mkt-RF_tstat  SMB_coef  SMB_tstat  \
# 20      0.0150       0.2928       0.5905        4.2181   -0.2982    -1.0729
# 21     -0.0475      -0.9226       1.0694        4.4330    0.2075     0.4284
# 22      0.0143       0.8464       1.4523        7.7504    0.1165     0.3063
# 23     -0.0055      -0.1365       0.5715        3.8189   -0.1349    -0.4515
# 24     -0.0016      -0.0352       0.5438        4.1842   -0.1665    -0.6537
# 25      0.0130       0.2339       0.4359        2.8596    0.1288     0.4204
# 26      0.0031       0.1070       0.5331        4.5137   -0.3662    -1.5702
# 27      0.0087       0.3503       0.5851        4.3971   -0.1311    -0.5019
# 28     -0.1168      -1.5242       0.5131        3.2404   -0.0615    -0.1903
# 29     -0.0307      -0.9346       0.8116        7.0164   -0.0580    -0.2520
# 30     -0.0361      -0.4220       1.5644        7.3157    0.1039     0.2445
# 31     -0.0143      -0.3672       0.4711        3.5728   -0.3492    -1.3407
# 32     -0.3998      -1.6659       1.1185        6.9717   -0.3420    -1.0959
#
#     HML_coef  HML_tstat  RMW_coef  RMW_tstat  CMA_coef  CMA_tstat  \
# 20    0.1033     0.4372    0.1046     0.3311    0.3831     1.1275
# 21    0.0436     0.1076   -0.2866    -0.5221    0.7071     1.1843
# 22   -0.4853    -1.4638    0.3420     0.8067    0.0066     0.0144
# 23    0.1638     0.6438    0.0469     0.1403    0.2468     0.6694
# 24    0.1601     0.7279    0.4391     1.5316    0.4543     1.4433
# 25    0.0979     0.3641    0.3929     1.1404    0.0166     0.0458
# 26    0.2969     1.4841    0.0251     0.0943    0.4509     1.5892
# 27    0.0470     0.2086    0.4157     1.3941    0.3054     0.9741
# 28    0.1668     0.6032    0.5906     1.6181    0.4013     1.0269
# 29    0.1600     0.8320    0.4181     1.5588    0.5358     1.9380
# 30    1.6731     4.6839   -0.5069    -1.0439    0.3126     0.5955
# 31   -0.0327    -0.1454    0.3938     1.3136    0.5489     1.7376
# 32    0.7354     2.7816   -0.0211    -0.0583    0.1906     0.5061
#
#     Overall_ESG_Exposure_coef  Overall_ESG_Exposure_tstat  \
# 20                    -0.3989                     -0.8799
# 21                     0.2747                      1.2028
# 22                    12.5560                      0.6564
# 23                     0.0635                      0.6479
# 24                     0.0370                      0.2141
# 25                    -0.5009                     -1.2790
# 26                    -0.0992                     -0.9657
# 27                    -0.0414                     -0.5366
# 28                     0.1157                      0.8187
# 29                     0.2589                      1.2337
# 30                     0.0000                      0.0001
# 31                     0.0227                      0.4014
# 32                     0.9861                      1.5617
#
#     Overall_ESG_Sentiment_coef  Overall_ESG_Sentiment_tstat      R2  Adj_R2  \
# 20                      0.3290                       1.0142  0.2797  0.1983
# 21                     -0.4668                      -1.6340  0.3383  0.2636
# 22                     -0.3882                      -0.7681  0.5691  0.5204
# 23                     -0.0643                      -0.3936  0.2547  0.1706
# 24                     -0.0562                      -0.4342  0.3570  0.2845
# 25                      0.3245                       1.9358  0.2414  0.1558
# 26                      0.0884                       1.3490  0.3824  0.3127
# 27                      0.0293                       0.4847  0.3223  0.2458
# 28                      0.4066                       1.5911  0.2664  0.1836
# 29                     -0.1623                      -1.1022  0.5454  0.4941
# 30                      0.1476                       0.6132  0.7052  0.6719
# 31                     -0.0154                      -0.1193  0.2748  0.1930
# 32                      0.3728                       1.8077  0.5631  0.5138
#
#           Macro_Sector Ticker
# 20  Energy & Utilities    AEP
# 21  Energy & Utilities    AES
# 22  Energy & Utilities    EFX
# 23  Energy & Utilities   EVRG
# 24  Energy & Utilities    EXC
# 25  Energy & Utilities     FE
# 26  Energy & Utilities     NI
# 27  Energy & Utilities    PEG
# 28  Energy & Utilities    PNW
# 29  Energy & Utilities    PPL
# 30  Energy & Utilities    SLB
# 31  Energy & Utilities    WEC
# 32  Energy & Utilities    WMB
#
# Done! All tables printed.
